# %% [markdown]
# # Recommendation Systems project

# %% [markdown]
# ## Introduction

# %% [markdown]
# **DOMAIN**: Smartphone, Electronics
#
# **CONTEXT**: India is the second largest market globally for smartphones after China. About 134 million smartphones were sold across India
# in the year 2017 and is estimated to increase to about 442 million in 2022. India ranked second in the average time spent on mobile web by
# smartphone users across Asia Pacific. The combination of very high sales volumes and the average smartphone consumer behaviour has
# made India a very attractive market for foreign vendors. As per Consumer behaviour, 97% of consumers turn to a search engine when they
# are buying a product vs. 15% who turn to social media. If a seller succeeds to publish smartphones based on user’s behaviour/choice at the
# right place, there are 90% chances that user will enquire for the same. This Case Study is targeted to build a recommendation system
# based on individual consumer’s behaviour or choice.

# %% [markdown]
# **DATA DESCRIPTION**:
#
# • author : name of the person who gave the rating
#
# • country : country the person who gave the rating belongs to
#
# • data : date of the rating
#
# • domain: website from which the rating was taken from
#
# • extract: rating content
#
# • language: language in which the rating was given
#
# • product: name of the product/mobile phone for which the rating was given
#
# • score: average rating for the phone
#
# • score_max: highest rating given for the phone
#
# • source: source from where the rating was taken

# %% [markdown]
# Import the necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# !pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.4)

# %%
from collections import defaultdict
from surprise import SVD
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split

# %%
phone1 = pd.read_csv('phone_user_review_file_1.csv', encoding='latin-1')
phone2 = pd.read_csv('phone_user_review_file_2.csv', encoding='latin-1')
phone3 = pd.read_csv('phone_user_review_file_3.csv', encoding='latin-1')
phone4 = pd.read_csv('phone_user_review_file_4.csv', encoding='latin-1')
phone5 = pd.read_csv('phone_user_review_file_5.csv', encoding='latin-1')
phone6 = pd.read_csv('phone_user_review_file_6.csv', encoding='latin-1')

# %%
phone1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374910 entries, 0 to 374909
# Data columns (total 11 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   phone_url  374910 non-null  object
#  1   date       374910 non-null  object
#  2   lang       374910 non-null  object
#  3   country    374910 non-null  object
#  4   source     374910 non-null  object
#  5   domain     374910 non-null  object
#  6   score      366691 non-null  float64
#  7   score_max  366691 non-null  float64
#  8   extract    371934 non-null  object
#  9   author     371641 non-null  object
#  10  product    374910 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 31.5+ MB

# %%
phone1.shape
# Out:
# (374910, 11)

# %%
phone2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114925 entries, 0 to 114924
# Data columns (total 11 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   phone_url  114925 non-null  object
#  1   date       114925 non-null  object
#  2   lang       114925 non-null  object
#  3   country    114925 non-null  object
#  4   source     114925 non-null  object
#  5   domain     114925 non-null  object
#  6   score      112166 non-null  float64
#  7   score_max  112166 non-null  float64
#  8   extract    113965 non-null  object
#  9   author     113290 non-null  object
#  10  product    114925 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 9.6+ MB

# %%
phone2.shape
# Out:
# (114925, 11)

# %% [markdown]
# Merge all the datasets into one dataframe

# %%
data_df = pd.concat([phone1, phone2, phone3, phone4, phone5, phone6], axis=0)
data_df.head()
# Out:
#                         phone_url       date lang country            source  \
# 0  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us  Verizon Wireless
# 1  /cellphones/samsung-galaxy-s8/  4/28/2017   en      us       Phone Arena
# 2  /cellphones/samsung-galaxy-s8/   5/4/2017   en      us            Amazon
# 3  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us           Samsung
# 4  /cellphones/samsung-galaxy-s8/  5/11/2017   en      us  Verizon Wireless
#
#                 domain  score  score_max  \
# 0  verizonwireless.com   10.0       10.0
# 1       phonearena.com   10.0       10.0
# 2           amazon.com    6.0       10.0
# 3          samsung.com    9.2       10.0
# 4  verizonwireless.com    4.0       10.0
#
#                                              extract       author  \
# 0  As a diehard Samsung fan who has had every Sam...   CarolAnn35
# 1  Love the phone. the phone is sleek and smooth ...    james0923
# 2  Adequate feel. Nice heft. Processor's still sl...     R. Craig
# 3  Never disappointed. One of the reasons I've be...  Buster2020
# 4  I've now found that i'm in a group of people t...   S Ate Mine
#
#                                              product
# 0                                  Samsung Galaxy S8
# 1                                  Samsung Galaxy S8
# 2  Samsung Galaxy S8 (64GB) G950U 5.8" 4G LTE Unl...
# 3                      Samsung Galaxy S8 64GB (AT&T)
# 4                                  Samsung Galaxy S8

# %% [markdown]
# ## Data Preparation and Analysis

# %%
data_df.shape
# Out:
# (1415133, 11)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1415133 entries, 0 to 163836
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1415133 non-null  object
#  1   date       1415133 non-null  object
#  2   lang       1415133 non-null  object
#  3   country    1415133 non-null  object
#  4   source     1415133 non-null  object
#  5   domain     1415133 non-null  object
#  6   score      1351644 non-null  float64
#  7   score_max  1351644 non-null  float64
#  8   extract    1395772 non-null  object
#  9   author     1351931 non-null  object
#  10  product    1415132 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 129.6+ MB

# %%
data_df.describe()
# Out:
#               score  score_max
# count  1.351644e+06  1351644.0
# mean   8.007060e+00       10.0
# std    2.616121e+00        0.0
# min    2.000000e-01       10.0
# 25%    7.200000e+00       10.0
# 50%    9.200000e+00       10.0
# 75%    1.000000e+01       10.0
# max    1.000000e+01       10.0

# %%
data_df['product'].value_counts(ascending=False)
# Out:
# Lenovo Vibe K4 Note (White,16GB)           5226
# Lenovo Vibe K4 Note (Black, 16GB)          4390
# OnePlus 3 (Graphite, 64 GB)                4103
# OnePlus 3 (Soft Gold, 64 GB)               3563
# Huawei P8lite zwart / 16 GB                2707
#                                            ...
# JiaYu G4 Advanced (Black)                     1
# SAMSUNG M140 CEP TELEFONU                     1
# Samsung SGH-M140                              1
# Sony Xperia tipo schwarz                      1
# HTC Desire 601 - 8GB - Black Smartphone       1
# Name: product, Length: 61313, dtype: int64

# %% [markdown]
# Except score and score_max (which are of float type) all other features are of object type
#
# score_max has the maximum score or rating to be provided and is a constant - 10 throughout
#
# Same product has multiple names with different features, they can be considered as a single product. For example, Lenovo Vibe K4 Note has White, black etc but can be considered as a single product

# %% [markdown]
# Round off scores to the nearest integers

# %%
data_df['score'] = round(data_df['score']).astype('Int64')

# %%
data_df.head()
# Out:
#                         phone_url       date lang country            source  \
# 0  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us  Verizon Wireless
# 1  /cellphones/samsung-galaxy-s8/  4/28/2017   en      us       Phone Arena
# 2  /cellphones/samsung-galaxy-s8/   5/4/2017   en      us            Amazon
# 3  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us           Samsung
# 4  /cellphones/samsung-galaxy-s8/  5/11/2017   en      us  Verizon Wireless
#
#                 domain  score  score_max  \
# 0  verizonwireless.com     10       10.0
# 1       phonearena.com     10       10.0
# 2           amazon.com      6       10.0
# 3          samsung.com      9       10.0
# 4  verizonwireless.com      4       10.0
#
#                                              extract       author  \
# 0  As a diehard Samsung fan who has had every Sam...   CarolAnn35
# 1  Love the phone. the phone is sleek and smooth ...    james0923
# 2  Adequate feel. Nice heft. Processor's still sl...     R. Craig
# 3  Never disappointed. One of the reasons I've be...  Buster2020
# 4  I've now found that i'm in a group of people t...   S Ate Mine
#
#                                              product
# 0                                  Samsung Galaxy S8
# 1                                  Samsung Galaxy S8
# 2  Samsung Galaxy S8 (64GB) G950U 5.8" 4G LTE Unl...
# 3                      Samsung Galaxy S8 64GB (AT&T)
# 4                                  Samsung Galaxy S8

# %% [markdown]
# Check for missing values and impute them

# %%
data_df.isnull().sum()
# Out:
# phone_url        0
# date             0
# lang             0
# country          0
# source           0
# domain           0
# score        63489
# score_max    63489
# extract      19361
# author       63202
# product          1
# dtype: int64

# %%
data_df['author'].value_counts(ascending=False)
# Out:
# Amazon Customer                    76978
# Cliente Amazon                     19304
# e-bit                               8663
# Client d'Amazon                     7716
# Amazon Kunde                        4750
#                                    ...
# Julen Crespo Arocena                   1
# Sigfrido                               1
# Alex Torres                            1
# Maria Concepcion AndrÃ©s LÃ³pez        1
# claudia0815                            1
# Name: author, Length: 801103, dtype: int64

# %%
data_df['phone_url'].value_counts(ascending=False).head(50)
# Out:
# /cellphones/samsung-galaxy-s-iii/                                 17093
# /cellphones/apple-iphone-5s/                                      16379
# /cellphones/samsung-galaxy-s6/                                    16145
# /cellphones/samsung-galaxy-s5/                                    16082
# /cellphones/samsung-galaxy-s7-edge/                               15917
# /cellphones/motorola-moto-g/                                      14476
# /cellphones/samsung-galaxy-s7-789999/                             13488
# /cellphones/samsung-i9500-galaxy-s-iv/                            13161
# /cellphones/huawei-p8-lite/                                       12629
# /cellphones/lenovo-vibe-k4-note/                                   9662
# /cellphones/samsung-galaxy-s4-mini-gt-i9190-gt-i9192-dual-sim/     9027
# /cellphones/samsung-galaxy-s6-edge-sm-g925f/                       8844
# /cellphones/apple-iphone-4s/                                       8602
# /cellphones/samsung-galaxy-s3-mini/                                8388
# /cellphones/lg-g3-d855-657484/                                     7992
# /cellphones/oneplus-3/                                             7944
# /cellphones/lenovo-vibe-k5/                                        7892
# /cellphones/apple-iphone-5/                                        7821
# /cellphones/apple-iphone-6/                                        7820
# /cellphones/apple-iphone-4/                                        7289
# /cellphones/lg-g4/                                                 7060
# /cellphones/lg-g2-594708/                                          6621
# /cellphones/apple-iphone-5c/                                       6157
# /cellphones/apple-iphone-6s/                                       6137
# /cellphones/samsung-galaxy-ace-s5830/                              6064
# /cellphones/motorola-moto-e/                                       6031
# /cellphones/samsung-galaxy-j3-duos/                                5936
# /cellphones/apple-iphone-7/                                        5839
# /cellphones/samsung-s5230/                                         5824
# /cellphones/samsung-galaxy-note-iii/                               5806
# /cellphones/huawei-p9-lite/                                        5553
# /cellphones/samsung-galaxy-s-ii/                                   5425
# /cellphones/nokia-5800-xpressmusic-tube/                           5179
# /cellphones/samsung-galaxy-note-2/                                 5001
# /cellphones/samsung-galaxy-j5/                                     4933
# /cellphones/samsung-galaxy-note-4/                                 4885
# /cellphones/nokia-lumia-520/                                       4883
# /cellphones/samsung-galaxy-s6-edgeplus/                            4776
# /cellphones/motorola-moto-g3/                                      4619
# /cellphones/lg-google-nexus-5/                                     4549
# /cellphones/microsoft-lumia-640-dual-sim/                          4523
# /cellphones/apple-iphone-se/                                       4425
# /cellphones/motorola-moto-g4/                                      4420
# /cellphones/htc-one-m7/                                            4349
# /cellphones/nokia-lumia-630/                                       4187
# /cellphones/google-nexus-5x-h791/                                  4169
# /cellphones/samsung-galaxy-a3-2016/                                4025
# /cellphones/asus-zenfone-2/                                        3980
# /cellphones/nokia-n95/                                             3912
# /cellphones/sony-xperia-z3-compact/                                3870
# Name: phone_url, dtype: int64

# %%
data_df[data_df["phone_url"]=='/cellphones/samsung-galaxy-s-iii/'][['product']].value_counts()
# Out:
# product
# Samsung Galaxy Express I8730                                                                                                                        2685
# Samsung Galaxy S III 16GB (Virgin Mobile)                                                                                                            730
# Samsung Galaxy S III                                                                                                                                 689
# Samsung Galaxy S III 16GB (Straight Talk)                                                                                                            556
# Samsung Galaxy S III i9300 Smartphone 16 GB (12,2 cm (4,8 Zoll) HD Super-AMOLED-Touchscreen, 8 Megapixel Kamera, Micro-SIM, Android 4.0) schwarz     381
#                                                                                                                                                     ...
# Samsung Galaxy SIII I9300 noir/bleue 16Go / GB dÃ©bloquÃ©, logiciel original,                                                                          1
# Samsung Galaxy S III (I9300) - Smartphone libre Android (pantalla 4.8", c??mara 8 Mp, 16 GB, Quad-Core 1.4 GHz, 1 GB RAM), negro (importado)           1
# Samsung Galaxy S3 (i9300) - Smartphone libre Android (pantalla 4.8", cÃ¡mara 8 Mp, 16 GB, Quad-Core 1.4 GHz, 1 GB RAM), azul                           1
# Slava Zaitsev Maroussia - Eau de Toilette                                                                                                              1
# Jean Paul Gaultier Le Beau Male - Eau de Toilette                                                                                                      1
# Length: 377, dtype: int64

# %%
data_df[data_df["phone_url"]=='/cellphones/apple-iphone-5s/'][['product']].value_counts()
# Out:
# product
# Apple iPhone 5s (Silver, 16GB)                                                                                           1603
# Apple iPhone 5s 16GB (ÑÐµÑÐµÐ±ÑÐ¸ÑÑÑÐ¹)                                                                            1355
# Apple iPhone 5s GSM Unlocked Cellphone, 16 GB, Space Gray                                                                1273
# Apple iPhone 5s (Gold, 16GB)                                                                                              682
# Apple iPhone 5s 16GB (ÑÐµÑÑÐ¹ ÐºÐ¾ÑÐ¼Ð¾Ñ)                                                                            592
#                                                                                                                          ...
# Apple iPhone 5S (4", 16GB, 8MP, Space Grau)                                                                                 1
# Apple iPhone 5s 32Go GRIS                                                                                                   1
# Apple iPhone 5s Smartphone dÃ©bloquÃ© 4G (Ecran : 4 pouces - 16 Go - iOS 7) Argent (ReconditionnÃ© CertifiÃ© Grade A)       1
# Apple iPhone 5S 16GB Space Grey                                                                                             1
# Graco Dotastic Tote Nappy Bag                                                                                               1
# Length: 559, dtype: int64

# %% [markdown]
# There are multiple names for the same product. So let's use phone name and model number rather than other details mentioned in 'product' column

# %%
data_df['phone'] = data_df['phone_url'].str.split("/").apply(lambda col: col[2]).replace('-', ' ', regex=True)
data_df['product'] = data_df['phone']
data_df['phone'].unique()
# Out:
# array(['samsung galaxy s8', 'samsung galaxy s6 edgeplus',
#        'samsung galaxy s8 plus', ..., 'siemens c10', 'maxon mx 3204',
#        'alcatel ot club_1187'], dtype=object)

# %%
product = data_df['product'].value_counts()
print('Distribution of number of ratings per item: \n',product)
# Out:
# Distribution of number of ratings per item:
#  samsung galaxy s iii      17093
# apple iphone 5s           16379
# samsung galaxy s6         16145
# samsung galaxy s5         16082
# samsung galaxy s7 edge    15917
#                           ...
# blu quattro 5 7 hd            1
# lg vx3450                     1
# blackberry 7105t              1
# o2 xda nova                   1
# samsung chrono 2              1
# Name: product, Length: 5556, dtype: int64

# %%
data_df.isnull().sum()
# Out:
# phone_url        0
# date             0
# lang             0
# country          0
# source           0
# domain           0
# score        63489
# score_max    63489
# extract      19361
# author       63202
# product          0
# phone            0
# dtype: int64

# %% [markdown]
# Check for duplicate values in the data and impute them

# %%
data_df.duplicated().sum()
# Out:
# 24895

# %% [markdown]
# Impute null 'scores' with the median

# %%
data_df['score'] = data_df['score'].fillna(data_df['score'].median())

# %% [markdown]
# Drop the rows with null values

# %%
data_df.dropna(inplace=True)

# %%
data_df.shape
# Out:
# (1275917, 12)

# %% [markdown]
# Remove rows where author is unknown or Anonymous

# %%
data_df = data_df[(data_df["author"] != 'Anonymous')&(data_df["author"] != 'unknown')&(data_df["author"] != 'Anonymous ')]

# %%
data_df.shape
# Out:
# (1270117, 12)

# %% [markdown]
# Drop duplicates

# %%
data_df = data_df.drop_duplicates()

# %% [markdown]
# Keep only 1 Million data samples

# %%
finaldata1_df = data_df.sample(n=1000000, random_state=612)

# %% [markdown]
# Drop irrelevant features. Keep features like Author, Product, and Score

# %%
relevant_features=['author','product','score']

# %%
finaldata_df = finaldata1_df.loc[:,relevant_features]

# %%
finaldata_df.shape
# Out:
# (1000000, 3)

# %%
finaldata_df.describe()
# Out:
#            score
# count  1000000.0
# mean    7.999746
# std      2.62816
# min          0.0
# 25%          7.0
# 50%          9.0
# 75%         10.0
# max         10.0

# %%
finaldata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 47055 to 188972
# Data columns (total 3 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   author   1000000 non-null  object
#  1   product  1000000 non-null  object
#  2   score    1000000 non-null  Int64
# dtypes: Int64(1), object(2)
# memory usage: 31.5+ MB

# %% [markdown]
# Identify the most rated products

# %%
# Top 10 most rated products
finaldata_df['product'].value_counts(ascending=False)[:10]
# Out:
# samsung galaxy s6            12399
# samsung galaxy s7 edge       11973
# apple iphone 5s              11687
# samsung galaxy s5            11553
# motorola moto g              11409
# samsung galaxy s iii         10794
# samsung galaxy s7 789999     10201
# huawei p8 lite                9850
# samsung i9500 galaxy s iv     9688
# lenovo vibe k4 note           7724
# Name: product, dtype: int64

# %% [markdown]
# Identify the users with most number of reviews

# %%
# Top 10 users with most number of reviews
finaldata_df['author'].value_counts(ascending=False)[:10]
# Out:
# Amazon Customer    61346
# Cliente Amazon     15334
# e-bit               6699
# Client d'Amazon     6124
# Amazon Kunde        3778
# einer Kundin        2084
# einem Kunden        1524
# David                747
# Marco                680
# Alex                 630
# Name: author, dtype: int64

# %% [markdown]
# Select data with products having more than 50 ratings and users who have given more than 50 ratings

# %%
topauthors = finaldata_df['author'].value_counts()
top50author = topauthors[topauthors > 50].index.tolist()

topproducts = finaldata_df['product'].value_counts()
top50product = topproducts[topproducts > 50].index.tolist()

finaltop50_df = finaldata_df[(finaldata_df['author'].isin(top50author)) & (finaldata_df['product'].isin(top50product))]
finaltop50_df.shape
# Out:
# (165453, 3)

# %% [markdown]
# **Build a popularity based model and recommend top 5 mobile phones**

# %% [markdown]
# Build model for top 50 products and authors

# %%
# Determine average score for each product
ratings = pd.DataFrame(finaltop50_df.groupby('product')['score'].mean())

# Determine count of ratings for each product
ratings['count'] = finaltop50_df.groupby('product')['score'].count()

# Sort by average score and count of ratings to get the most popular phones
ratings = ratings.sort_values(by=['score','count'], ascending=[False,False])

ratings.head()
# Out:
#                  score  count
# product
# samsung f400      10.0     10
# nokia 5140i       10.0      9
# nokia 5250        10.0      9
# pantech caper     10.0      7
# huawei ideos x5   10.0      4

# %% [markdown]
# Build model for all products

# %%
# Determine average score for each product
overall_ratings = pd.DataFrame(finaldata_df.groupby('product')['score'].mean())

# Determine count of ratings for each product
overall_ratings['count'] = finaldata_df.groupby('product')['score'].count()

# Sort by average score and count of ratings to get the most popular phones
overall_ratings = overall_ratings.sort_values(by=['score','count'], ascending=[False,False])

overall_ratings.head()
# Out:
#                    score  count
# product
# xiaomi mi 5s        10.0     11
# verykool t742       10.0      7
# thl w7s             10.0      6
# lg p503             10.0      5
# supersonic sc 150   10.0      5

# %% [markdown]
# **Build a collaborative filtering model using SVD**

# %%
data = Dataset.load_from_df(finaltop50_df[['author','product','score']], Reader(rating_scale=(1, 10)))
data.df.head()
# Out:
#                  author                     product  score
# 218434         Wolfgang               lg gd880 mini     10
# 336129           Carlos             motorola moto g     10
# 37957   Client d'Amazon    samsung galaxy s7 789999     10
# 58575   Amazon Customer                lenovo a2010     10
# 369807            e-bit  samsung galaxy grand prime     10

# %%
trainset, testset = train_test_split(data, test_size=.25,random_state=123)

# %%
svd_model = SVD(n_factors=5, biased=False, random_state=123)
svd_model.fit(trainset)
test_pred = svd_model.test(testset)

# %% [markdown]
# Evaluate the collaborative model

# %%
svd_rmse = accuracy.rmse(test_pred)
# Out:
# RMSE: 2.8687

# %% [markdown]
# **Collaborative filtering model using kNNWithMeans_Item based**

# %%
knn_item = KNNWithMeans(k=10, sim_options={ 'user_based': False})
knn_item.fit(trainset)
knn_item_pred = knn_item.test(testset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
knn_item_rmse = accuracy.rmse(knn_item_pred)
# Out:
# RMSE: 2.8929

# %% [markdown]
# **Collaborative filtering model using kNNWithMeans_User based**

# %%
knn_user = KNNWithMeans(k=10, sim_options={ 'user_based': True})
knn_user.fit(trainset)
knn_user_pred = knn_user.test(testset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
knn_user_rmse = accuracy.rmse(knn_user_pred)
# Out:
# RMSE: 2.8711

# %%
print('RMSE for SVD: ',svd_rmse,'\nRMSE for KNN with Means item based: ',knn_item_rmse, '\nRMSE for KNN with Means user based:',knn_user_rmse)
# Out:
# RMSE for SVD:  2.8687414864304
# RMSE for KNN with Means item based:  2.8928916844465125
# RMSE for KNN with Means user based: 2.871138461778053

# %% [markdown]
# RMSE for the first SVD model is better than KNN with means item based or user based. The SVD model is the best model for the dataset.

# %% [markdown]
# Predict score (average rating) for test users.

# %%
test_pred[0]
# Out:
# Prediction(uid='Ð\x90Ð½Ð°Ñ\x81Ñ\x82Ð°Ñ\x81Ð¸Ñ\x8f', iid='apple iphone 5s', r_ui=10.0, est=9.48552336303562, details={'was_impossible': False})

# %%
svd_pred_df = pd.DataFrame(test_pred, columns=['uid', 'iid', 'rui', 'est', 'details'])
print('Average rating based on SVD')
print('average prediction for test users: ', svd_pred_df['est'].mean())
print('average rating by test users: ', svd_pred_df['rui'].mean())
print('average prediction error for test users: ', (svd_pred_df['rui'] - svd_pred_df['est']).abs().mean())
# Out:
# Average rating based on SVD
# average prediction for test users:  7.997427815215116
# average rating by test users:  7.761773522870128
# average prediction error for test users:  2.2386185286390776

# %%
knn_item_df = pd.DataFrame(knn_item_pred, columns=['uid', 'iid', 'rui', 'est', 'details'])
print('Average rating based on KNN with means item based')
print('average prediction for test users: ', knn_item_df['est'].mean())
print('average rating by test users: ', knn_item_df['rui'].mean())
print('average prediction error for test users: ', (knn_item_df['rui'] - knn_item_df['est']).abs().mean())
# Out:
# Average rating based on KNN with means item based
# average prediction for test users:  7.750485011789254
# average rating by test users:  7.761773522870128
# average prediction error for test users:  2.286957897278912

# %%
knn_user_df = pd.DataFrame(knn_user_pred, columns=['uid', 'iid', 'rui', 'est', 'details'])
print('Average rating based on KNN with means user based')
print('average prediction for test users: ', knn_user_df['est'].mean())
print('average rating by test users: ', knn_user_df['rui'].mean())
print('average prediction error for test users: ', (knn_user_df['rui'] - knn_user_df['est']).abs().mean())
# Out:
# Average rating based on KNN with means user based
# average prediction for test users:  7.822884012039611
# average rating by test users:  7.761773522870128
# average prediction error for test users:  2.2531803345853607

# %% [markdown]
# Inferences:

# %% [markdown]
# Most popular phone (rated 10 by highest number of people):
#  * Overall: xiaomi mi 5s
#  * Amongst top users: samsung f400
#
# Data overall is skewed by huge number of reviews by 'Amazon Customer'. There are multiple customers from Amazon categorized as 'Cliente Amazon', etc. Rather than categorizing them this way, it would be better to have the actual names of customers who provided a review of the product.
#
# For our dataset, SVD has provided a better model with lower RMSE than KNN item based and KNN user based

# %% [markdown]
# Recommend top 5 products for test users

# %%
tp = pd.DataFrame(test_pred)
tp.head()
# Out:
#                   uid                 iid  r_ui       est  \
# 0  ÐÐ½Ð°ÑÑÐ°ÑÐ¸Ñ     apple iphone 5s  10.0  9.485523
# 1  ÐÐ»ÐµÐºÑÐ°Ð½Ð´Ñ  sony xperia acro s  10.0  7.696370
# 2     Client d'Amazon      huawei honor 7  10.0  9.404716
# 3     Amazon Customer        xiaomi mi 4i  10.0  8.060954
# 4      Cliente Amazon   xiaomi redmi note   8.0  5.735508
#
#                      details
# 0  {'was_impossible': False}
# 1  {'was_impossible': False}
# 2  {'was_impossible': False}
# 3  {'was_impossible': False}
# 4  {'was_impossible': False}

# %%
top = tp.groupby(['uid','iid']).agg({'r_ui': np.average}).sort_values(['uid','r_ui','iid'], ascending=[False,False,True])
top
# Out:
#                              r_ui
# uid      iid
# Ð®ÑÐ¸Ð¹ apple iphone 5s     10.0
#          asus zenfone 2      10.0
#          htc desire x        10.0
#          htc one m7          10.0
#          motorola moto g     10.0
# ...                           ...
# #        nokia 5310 xm        6.0
#          nokia n8             6.0
#          samsung b5722        6.0
#          samsung b7722        6.0
#          sony ericsson c510   6.0
#
# [17380 rows x 1 columns]

# %%
top5 = top.groupby('uid').head(5)
print(top5)
# Out:
#                              r_ui
# uid      iid
# Ð®ÑÐ¸Ð¹ apple iphone 5s     10.0
#          asus zenfone 2      10.0
#          htc desire x        10.0
#          htc one m7          10.0
#          motorola moto g     10.0
# ...                           ...
# #        apple iphone 4      10.0
#          nokia 5230          10.0
#          nokia 5233          10.0
#          nokia 6120 classic  10.0
#          nokia 6680          10.0
#
# [3095 rows x 1 columns]

# %%
# Retrieve top 5 products for all users
for item,value in top5.iterrows():
  print(item)
# Out:
# ('Ð®Ñ\x80Ð¸Ð¹', 'apple iphone 5s')
# ('Ð®Ñ\x80Ð¸Ð¹', 'asus zenfone 2')
# ('Ð®Ñ\x80Ð¸Ð¹', 'htc desire x')
# ('Ð®Ñ\x80Ð¸Ð¹', 'htc one m7')
# ('Ð®Ñ\x80Ð¸Ð¹', 'motorola moto g')
# ('Ð®Ð»Ð¸Ñ\x8f', 'apple iphone 5s')
# ('Ð®Ð»Ð¸Ñ\x8f', 'apple iphone 6')
# ('Ð®Ð»Ð¸Ñ\x8f', 'apple iphone se')
# ('Ð®Ð»Ð¸Ñ\x8f', 'htc one sv')
# ('Ð®Ð»Ð¸Ñ\x8f', 'huawei g610')
# ('Ð¢Ð°Ñ\x82Ñ\x8cÑ\x8fÐ½Ð°', 'apple iphone 5s')
# ('Ð¢Ð°Ñ\x82Ñ\x8cÑ\x8fÐ½Ð°', 'htc one mini')
# ('Ð¢Ð°Ñ\x82Ñ\x8cÑ\x8fÐ½Ð°', 'nokia c2 03')
# ('Ð¢Ð°Ñ\x82Ñ\x8cÑ\x8fÐ½Ð°', 'samsung galaxy a5')
# ('Ð¢Ð°Ñ\x82Ñ\x8cÑ\x8fÐ½Ð°', 'samsung galaxy j1 2016 4 5 sm j120')
# ('Ð¡ÐµÑ\x80Ð³ÐµÐ¹', 'apple iphone 6 plus')
# ('Ð¡ÐµÑ\x80Ð³ÐµÐ¹', 'apple iphone 6s')
# ('Ð¡ÐµÑ\x80Ð³ÐµÐ¹', 'htc wildfire s')
# ('Ð¡ÐµÑ\x80Ð³ÐµÐ¹', 'huawei honor 2')
# ('Ð¡ÐµÑ\x80Ð³ÐµÐ¹', 'huawei u8500')
# ('Ð¡Ð²ÐµÑ\x82Ð»Ð°Ð½Ð°', 'lenovo ideaphone s960')
# ('Ð¡Ð²ÐµÑ\x82Ð»Ð°Ð½Ð°', 'lg gt540')
# ('Ð¡Ð²ÐµÑ\x82Ð»Ð°Ð½Ð°', 'nokia asha 200')
# ('Ð¡Ð²ÐµÑ\x82Ð»Ð°Ð½Ð°', 'samsung galaxy a3 819970')
# ('Ð¡Ð²ÐµÑ\x82Ð»Ð°Ð½Ð°', 'samsung galaxy s4 mini gt i9190 gt i9192 dual sim')
# ('Ð¡Ð°Ñ\x88Ð°', 'asus zenfone 2')
# ('Ð¡Ð°Ñ\x88Ð°', 'htc one m7')
# ('Ð¡Ð°Ñ\x88Ð°', 'lenovo a2010')
# ('Ð¡Ð°Ñ\x88Ð°', 'lg optimus l5 ii dual e455 optimus duet')
# ('Ð¡Ð°Ñ\x88Ð°', 'samsung galaxy j1 2016 4 5 sm j120')
# ('Ð\xa0Ñ\x83Ñ\x81Ð»Ð°Ð½', 'apple iphone 5s')
# ('Ð\xa0Ñ\x83Ñ\x81Ð»Ð°Ð½', 'apple iphone se')
# ('Ð\xa0Ñ\x83Ñ\x81Ð»Ð°Ð½', 'lg l90 d410')
# ('Ð\xa0Ñ\x83Ñ\x81Ð»Ð°Ð½', 'nokia n8')
# ('Ð\xa0Ñ\x83Ñ\x81Ð»Ð°Ð½', 'nokia n97 mini')
# ('Ð\xa0Ð¾Ð¼Ð°Ð½', 'huawei g6600')
# ('Ð\xa0Ð¾Ð¼Ð°Ð½', 'lg optimus hub e510')
# ('Ð\xa0Ð¾Ð¼Ð°Ð½', 'nokia lumia 920')
# ('Ð\xa0Ð¾Ð¼Ð°Ð½', 'samsung focus flash')
# ('Ð\xa0Ð¾Ð¼Ð°Ð½', 'samsung g7102 galaxy grand 2')
# ('Ð\x9fÐ¾Ð»Ñ\x8cÐ·Ð¾Ð²Ð°Ñ\x82ÐµÐ»Ñ\x8c Ñ\x81ÐºÑ\x80Ñ\x8bÐ» Ñ\x81Ð²Ð¾Ð¸ Ð´Ð°Ð½Ð½Ñ\x8bÐµ', 'alcatel one touch pixi 3')
# ('Ð\x9fÐ¾Ð»Ñ\x8cÐ·Ð¾Ð²Ð°Ñ\x82ÐµÐ»Ñ\x8c Ñ\x81ÐºÑ\x80Ñ\x8bÐ» Ñ\x81Ð²Ð¾Ð¸ Ð´Ð°Ð½Ð½Ñ\x8bÐµ', 'apple iphone 5c')
# ('Ð\x9fÐ¾Ð»Ñ\x8cÐ·Ð¾Ð²Ð°Ñ\x82ÐµÐ»Ñ\x8c Ñ\x81ÐºÑ\x80Ñ\x8bÐ» Ñ\x81Ð²Ð¾Ð¸ Ð´Ð°Ð½Ð½Ñ\x8bÐµ', 'apple iphone 6 plus')
# ('Ð\x9fÐ¾Ð»Ñ\x8cÐ·Ð¾Ð²Ð°Ñ\x82ÐµÐ»Ñ\x8c Ñ\x81ÐºÑ\x80Ñ\x8bÐ» Ñ\x81Ð²Ð¾Ð¸ Ð´Ð°Ð½Ð½Ñ\x8bÐµ', 'asus zenfone 3')
# ('Ð\x9fÐ¾Ð»Ñ\x8cÐ·Ð¾Ð²Ð°Ñ\x82ÐµÐ»Ñ\x8c Ñ\x81ÐºÑ\x80Ñ\x8bÐ» Ñ\x81Ð²Ð¾Ð¸ Ð´Ð°Ð½Ð½Ñ\x8bÐµ', 'doogee x5 pro')
# ('Ð\x9fÐ°Ð²ÐµÐ»', 'huawei u8500')
# ('Ð\x9fÐ°Ð²ÐµÐ»', 'nokia 225')
# ('Ð\x9fÐ°Ð²ÐµÐ»', 'nokia lumia 925')
# ('Ð\x9fÐ°Ð²ÐµÐ»', 'nokia x6')
# ('Ð\x9fÐ°Ð²ÐµÐ»', 'samsung e2370')
# ('Ð\x9eÐ»Ñ\x8cÐ³Ð°', 'apple iphone 6s plus')
# ('Ð\x9eÐ»Ñ\x8cÐ³Ð°', 'lenovo ideaphone a706')
# ('Ð\x9eÐ»Ñ\x8cÐ³Ð°', 'lenovo s660')
# ('Ð\x9eÐ»Ñ\x8cÐ³Ð°', 'nokia 101')
# ('Ð\x9eÐ»Ñ\x8cÐ³Ð°', 'nokia c2 03')
# ('Ð\x9eÐ»ÐµÐ³', 'alcatel one touch 997d ot 997d')
# ('Ð\x9eÐ»ÐµÐ³', 'apple iphone 5s')
# ('Ð\x9eÐ»ÐµÐ³', 'apple iphone 7')
# ('Ð\x9eÐ»ÐµÐ³', 'caterpillar b25')
# ('Ð\x9eÐ»ÐµÐ³', 'htc desire hd')
# ('Ð\x9dÐ¸ÐºÐ¾Ð»Ð°Ð¹', 'apple iphone 6 plus')
# ('Ð\x9dÐ¸ÐºÐ¾Ð»Ð°Ð¹', 'apple iphone se')
# ('Ð\x9dÐ¸ÐºÐ¾Ð»Ð°Ð¹', 'blackview bv5000')
# ('Ð\x9dÐ¸ÐºÐ¾Ð»Ð°Ð¹', 'caterpillar b25')
# ('Ð\x9dÐ¸ÐºÐ¾Ð»Ð°Ð¹', 'lenovo p780')
# ('Ð\x9dÐ¸ÐºÐ¸Ñ\x82Ð°', 'blackberry bold 9900')
# ('Ð\x9dÐ¸ÐºÐ¸Ñ\x82Ð°', 'lg k7')
# ('Ð\x9dÐ¸ÐºÐ¸Ñ\x82Ð°', 'lg optimus l3 e405')
# ('Ð\x9dÐ¸ÐºÐ¸Ñ\x82Ð°', 'motorola ex115')
# ('Ð\x9dÐ¸ÐºÐ¸Ñ\x82Ð°', 'nokia 5230')
# ('Ð\x9dÐ°Ñ\x82Ð°Ð»Ñ\x8cÑ\x8f', 'apple iphone 5s')
# ('Ð\x9dÐ°Ñ\x82Ð°Ð»Ñ\x8cÑ\x8f', 'htc desire 600')
# ('Ð\x9dÐ°Ñ\x82Ð°Ð»Ñ\x8cÑ\x8f', 'lenovo p780')
# ('Ð\x9dÐ°Ñ\x82Ð°Ð»Ñ\x8cÑ\x8f', 'lg optimus l1 ii e420')
# ('Ð\x9dÐ°Ñ\x82Ð°Ð»Ñ\x8cÑ\x8f', 'samsung galaxy a5')
# ('Ð\x9cÐ¸Ñ\x85Ð°Ð¸Ð»', 'apple iphone 5s')
# ('Ð\x9cÐ¸Ñ\x85Ð°Ð¸Ð»', 'apple iphone 7')
# ('Ð\x9cÐ¸Ñ\x85Ð°Ð¸Ð»', 'lg optimus l7')
# ('Ð\x9cÐ¸Ñ\x85Ð°Ð¸Ð»', 'nokia 2700 classic')
# ('Ð\x9cÐ¸Ñ\x85Ð°Ð¸Ð»', 'nokia lumia 520')
# ('Ð\x9cÐ°Ñ\x80Ð¸Ñ\x8f', 'lg x power')
# ('Ð\x9cÐ°Ñ\x80Ð¸Ñ\x8f', 'nokia 5230')
# ('Ð\x9cÐ°Ñ\x80Ð¸Ñ\x8f', 'samsung galaxy a5')
# ('Ð\x9cÐ°Ñ\x80Ð¸Ñ\x8f', 'samsung galaxy e5')
# ('Ð\x9cÐ°Ñ\x80Ð¸Ñ\x8f', 'samsung galaxy s6')
# ('Ð\x9cÐ°Ñ\x80Ð¸Ð½Ð°', 'apple iphone se')
# ('Ð\x9cÐ°Ñ\x80Ð¸Ð½Ð°', 'huawei g610')
# ('Ð\x9cÐ°Ñ\x80Ð¸Ð½Ð°', 'lenovo a2010')
# ('Ð\x9cÐ°Ñ\x80Ð¸Ð½Ð°', 'lenovo ideaphone a706')
# ('Ð\x9cÐ°Ñ\x80Ð¸Ð½Ð°', 'lg nexus 4')
# ('Ð\x9cÐ°ÐºÑ\x81Ð¸Ð¼', 'alcatel one touch idol 6030d')
# ('Ð\x9cÐ°ÐºÑ\x81Ð¸Ð¼', 'htc desire 530188')
# ('Ð\x9cÐ°ÐºÑ\x81Ð¸Ð¼', 'htc one mini')
# ('Ð\x9cÐ°ÐºÑ\x81Ð¸Ð¼', 'lg google nexus 5')
# ('Ð\x9cÐ°ÐºÑ\x81Ð¸Ð¼', 'lg p715 optimus l7 ii')
# ('Ð\x9aÐ¾Ð½Ñ\x81Ñ\x82Ð°Ð½Ñ\x82Ð¸Ð½', 'huawei honor 5x')
# ('Ð\x9aÐ¾Ð½Ñ\x81Ñ\x82Ð°Ð½Ñ\x82Ð¸Ð½', 'nokia lumia 930')
# ('Ð\x9aÐ¾Ð½Ñ\x81Ñ\x82Ð°Ð½Ñ\x82Ð¸Ð½', 'samsung galaxy a5')
# ('Ð\x9aÐ¾Ð½Ñ\x81Ñ\x82Ð°Ð½Ñ\x82Ð¸Ð½', 'samsung galaxy a5 2016')
# ('Ð\x9aÐ¾Ð½Ñ\x81Ñ\x82Ð°Ð½Ñ\x82Ð¸Ð½', 'samsung galaxy s7 edge')
# ('Ð\x9aÐ¸Ñ\x80Ð¸Ð»Ð»', 'lenovo ideaphone a316')
# ('Ð\x9aÐ¸Ñ\x80Ð¸Ð»Ð»', 'lg kp500')
# ('Ð\x9aÐ¸Ñ\x80Ð¸Ð»Ð»', 'motorola milestone xt720')
# ('Ð\x9aÐ¸Ñ\x80Ð¸Ð»Ð»', 'nokia c7 00i')
# ('Ð\x9aÐ¸Ñ\x80Ð¸Ð»Ð»', 'nokia lumia 1020')
# ('Ð\x98Ñ\x80Ð¸Ð½Ð°', 'apple iphone 5s')
# ('Ð\x98Ñ\x80Ð¸Ð½Ð°', 'apple iphone se')
# ('Ð\x98Ñ\x80Ð¸Ð½Ð°', 'htc desire 526g plus')
# ('Ð\x98Ñ\x80Ð¸Ð½Ð°', 'htc desire s')
# ('Ð\x98Ñ\x80Ð¸Ð½Ð°', 'lg optimus l3 ii e430 e425')
# ('Ð\x98Ð»Ñ\x8cÑ\x8f', 'apple iphone 5s')
# ('Ð\x98Ð»Ñ\x8cÑ\x8f', 'htc desire 620g')
# ('Ð\x98Ð»Ñ\x8cÑ\x8f', 'jiayu g4s')
# ('Ð\x98Ð»Ñ\x8cÑ\x8f', 'nokia lumia 930')
# ('Ð\x98Ð»Ñ\x8cÑ\x8f', 'nokia x2 00 358331')
# ('Ð\x98Ð³Ð¾Ñ\x80Ñ\x8c', 'huawei honor 8')
# ('Ð\x98Ð³Ð¾Ñ\x80Ñ\x8c', 'lg optimus l7')
# ('Ð\x98Ð³Ð¾Ñ\x80Ñ\x8c', 'lg p970')
# ('Ð\x98Ð³Ð¾Ñ\x80Ñ\x8c', 'nokia 5230')
# ('Ð\x98Ð³Ð¾Ñ\x80Ñ\x8c', 'nokia asha 230')
# ('Ð\x98Ð²Ð°Ð½', 'nokia lumia 925')
# ('Ð\x98Ð²Ð°Ð½', 'samsung galaxy a5')
# ('Ð\x98Ð²Ð°Ð½', 'samsung galaxy a5 2016')
# ('Ð\x98Ð²Ð°Ð½', 'samsung galaxy g130 young 2')
# ('Ð\x98Ð²Ð°Ð½', 'samsung galaxy j1 2016 4 5 sm j120')
# ('Ð\x95Ð»ÐµÐ½Ð°', 'apple iphone se')
# ('Ð\x95Ð»ÐµÐ½Ð°', 'htc desire s')
# ('Ð\x95Ð»ÐµÐ½Ð°', 'huawei ascend g750')
# ('Ð\x95Ð»ÐµÐ½Ð°', 'huawei p8 lite')
# ('Ð\x95Ð»ÐµÐ½Ð°', 'lenovo a1000 dual sim 4 mobile phone')
# ('Ð\x95ÐºÐ°Ñ\x82ÐµÑ\x80Ð¸Ð½Ð°', 'apple iphone 5s')
# ('Ð\x95ÐºÐ°Ñ\x82ÐµÑ\x80Ð¸Ð½Ð°', 'apple iphone se')
# ('Ð\x95ÐºÐ°Ñ\x82ÐµÑ\x80Ð¸Ð½Ð°', 'htc desire 820')
# ('Ð\x95ÐºÐ°Ñ\x82ÐµÑ\x80Ð¸Ð½Ð°', 'htc evo 3d')
# ('Ð\x95ÐºÐ°Ñ\x82ÐµÑ\x80Ð¸Ð½Ð°', 'jiayu g3s')
# ('Ð\x95Ð³Ð¾Ñ\x80', 'asus zenfone 6')
# ('Ð\x95Ð³Ð¾Ñ\x80', 'huawei g6600')
# ('Ð\x95Ð³Ð¾Ñ\x80', 'lg optimus l9 p760')
# ('Ð\x95Ð³Ð¾Ñ\x80', 'samsung galaxy j1 2016 4 5 sm j120')
# ('Ð\x95Ð³Ð¾Ñ\x80', 'sony xperia c')
# ('Ð\x95Ð²Ð³ÐµÐ½Ð¸Ñ\x8f', 'apple iphone 6s')
# ('Ð\x95Ð²Ð³ÐµÐ½Ð¸Ñ\x8f', 'nokia x2 02')
# ('Ð\x95Ð²Ð³ÐµÐ½Ð¸Ñ\x8f', 'samsung galaxy a5')
# ('Ð\x95Ð²Ð³ÐµÐ½Ð¸Ñ\x8f', 'samsung galaxy ace 3')
# ('Ð\x95Ð²Ð³ÐµÐ½Ð¸Ñ\x8f', 'samsung galaxy j5 4g lte 5 2 inches')
# ('Ð\x95Ð²Ð³ÐµÐ½Ð¸Ð¹', 'apple iphone 7')
# ('Ð\x95Ð²Ð³ÐµÐ½Ð¸Ð¹', 'htc incredible s')
# ('Ð\x95Ð²Ð³ÐµÐ½Ð¸Ð¹', 'htc one e8')
# ('Ð\x95Ð²Ð³ÐµÐ½Ð¸Ð¹', 'htc sensation')
# ('Ð\x95Ð²Ð³ÐµÐ½Ð¸Ð¹', 'htc wildfire s')
# ('Ð\x94Ð¼Ð¸Ñ\x82Ñ\x80Ð¸Ð¹', 'apple iphone 6s')
# ('Ð\x94Ð¼Ð¸Ñ\x82Ñ\x80Ð¸Ð¹', 'asus zenfone 2')
# ('Ð\x94Ð¼Ð¸Ñ\x82Ñ\x80Ð¸Ð¹', 'htc desire 310')
# ('Ð\x94Ð¼Ð¸Ñ\x82Ñ\x80Ð¸Ð¹', 'htc m8')
# ('Ð\x94Ð¼Ð¸Ñ\x82Ñ\x80Ð¸Ð¹', 'huawei g6600')
# ('Ð\x94Ð¸Ð¼Ð°', 'samsung g355 galaxy core ii')
# ('Ð\x94Ð¸Ð¼Ð°', 'samsung galaxy 3 i5800')
# ('Ð\x94Ð¸Ð¼Ð°', 'samsung galaxy j1')
# ('Ð\x94Ð¸Ð¼Ð°', 'samsung galaxy mega 5 8')
# ('Ð\x94Ð¸Ð¼Ð°', 'samsung galaxy s3 mini')
# ('Ð\x94ÐµÐ½Ð¸Ñ\x81', 'htc gratia')
# ('Ð\x94ÐµÐ½Ð¸Ñ\x81', 'htc wildfire s')
# ('Ð\x94ÐµÐ½Ð¸Ñ\x81', 'nokia 101')
# ('Ð\x94ÐµÐ½Ð¸Ñ\x81', 'prestigio multiphone 4040 duo')
# ('Ð\x94ÐµÐ½Ð¸Ñ\x81', 'samsung galaxy a3 819970')
# ('Ð\x94Ð°Ñ\x80Ñ\x8cÑ\x8f', 'nokia e52')
# ('Ð\x94Ð°Ñ\x80Ñ\x8cÑ\x8f', 'samsung galaxy a5')
# ('Ð\x94Ð°Ñ\x80Ñ\x8cÑ\x8f', 'samsung galaxy a5 2016')
# ('Ð\x94Ð°Ñ\x80Ñ\x8cÑ\x8f', 'samsung galaxy note 5 sm n920f')
# ('Ð\x94Ð°Ñ\x80Ñ\x8cÑ\x8f', 'sony xperia zr')
# ('Ð\x93Ð¾Ñ\x81Ñ\x82Ñ\x8c', 'apple iphone 7')
# ('Ð\x93Ð¾Ñ\x81Ñ\x82Ñ\x8c', 'google nexus 6p')
# ('Ð\x93Ð¾Ñ\x81Ñ\x82Ñ\x8c', 'nokia 6700 classic')
# ('Ð\x93Ð¾Ñ\x81Ñ\x82Ñ\x8c', 'samsung c3050')
# ('Ð\x93Ð¾Ñ\x81Ñ\x82Ñ\x8c', 'samsung champ gt c3300k')
# ('Ð\x92Ñ\x8fÑ\x87ÐµÑ\x81Ð»Ð°Ð²', 'apple iphone 5s')
# ('Ð\x92Ñ\x8fÑ\x87ÐµÑ\x81Ð»Ð°Ð²', 'lg optimus l3 ii e430 e425')
# ('Ð\x92Ñ\x8fÑ\x87ÐµÑ\x81Ð»Ð°Ð²', 'nokia c3')
# ('Ð\x92Ñ\x8fÑ\x87ÐµÑ\x81Ð»Ð°Ð²', 'nokia lumia 930')
# ('Ð\x92Ñ\x8fÑ\x87ÐµÑ\x81Ð»Ð°Ð²', 'samsung galaxy a5 2016')
# ('Ð\x92Ð»Ð°Ð´Ð¸Ñ\x81Ð»Ð°Ð²', 'apple iphone 4')
# ('Ð\x92Ð»Ð°Ð´Ð¸Ñ\x81Ð»Ð°Ð²', 'htc desire s')
# ('Ð\x92Ð»Ð°Ð´Ð¸Ñ\x81Ð»Ð°Ð²', 'huawei ascend g750')
# ('Ð\x92Ð»Ð°Ð´Ð¸Ñ\x81Ð»Ð°Ð²', 'nokia 101')
# ('Ð\x92Ð»Ð°Ð´Ð¸Ñ\x81Ð»Ð°Ð²', 'nokia asha 200')
# ('Ð\x92Ð»Ð°Ð´Ð¸Ð¼Ð¸Ñ\x80', 'asus zc551kl')
# ('Ð\x92Ð»Ð°Ð´Ð¸Ð¼Ð¸Ñ\x80', 'asus zenfone 2 laser ze601kl')
# ('Ð\x92Ð»Ð°Ð´Ð¸Ð¼Ð¸Ñ\x80', 'htc desire 530188')
# ('Ð\x92Ð»Ð°Ð´Ð¸Ð¼Ð¸Ñ\x80', 'htc desire 601')
# ('Ð\x92Ð»Ð°Ð´Ð¸Ð¼Ð¸Ñ\x80', 'huawei ascend g600')
# ('Ð\x92Ð»Ð°Ð´', 'acer liquid e2')
# ('Ð\x92Ð»Ð°Ð´', 'lg optimus l7')
# ('Ð\x92Ð»Ð°Ð´', 'samsung g7102 galaxy grand 2')
# ('Ð\x92Ð»Ð°Ð´', 'samsung i9500 galaxy s iv')
# ('Ð\x92Ð»Ð°Ð´', 'sony ericsson xperia mini')
# ('Ð\x92Ð¸Ñ\x82Ð°Ð»Ð¸Ð¹', 'alcatel one touch idol 6030d')
# ('Ð\x92Ð¸Ñ\x82Ð°Ð»Ð¸Ð¹', 'apple iphone 5s')
# ('Ð\x92Ð¸Ñ\x82Ð°Ð»Ð¸Ð¹', 'nokia 6303')
# ('Ð\x92Ð¸Ñ\x82Ð°Ð»Ð¸Ð¹', 'samsung c3222')
# ('Ð\x92Ð¸Ñ\x82Ð°Ð»Ð¸Ð¹', 'samsung galaxy a5 2016')
# ('Ð\x92Ð¸ÐºÑ\x82Ð¾Ñ\x80Ð¸Ñ\x8f', 'apple iphone 5s')
# ('Ð\x92Ð¸ÐºÑ\x82Ð¾Ñ\x80Ð¸Ñ\x8f', 'samsung galaxy j5')
# ('Ð\x92Ð¸ÐºÑ\x82Ð¾Ñ\x80Ð¸Ñ\x8f', 'samsung galaxy j7')
# ('Ð\x92Ð¸ÐºÑ\x82Ð¾Ñ\x80Ð¸Ñ\x8f', 'samsung galaxy s4 mini gt i9190 gt i9192 dual sim')
# ('Ð\x92Ð¸ÐºÑ\x82Ð¾Ñ\x80Ð¸Ñ\x8f', 'sony xperia c')
# ('Ð\x92Ð¸ÐºÑ\x82Ð¾Ñ\x80', 'apple iphone 5s')
# ('Ð\x92Ð¸ÐºÑ\x82Ð¾Ñ\x80', 'huawei ascend g700')
# ('Ð\x92Ð¸ÐºÑ\x82Ð¾Ñ\x80', 'motorola rokr e8')
# ('Ð\x92Ð¸ÐºÑ\x82Ð¾Ñ\x80', 'nokia 6700 classic')
# ('Ð\x92Ð¸ÐºÑ\x82Ð¾Ñ\x80', 'samsung galaxy a3')
# ('Ð\x92Ð°Ð´Ð¸Ð¼', 'apple iphone 5s')
# ('Ð\x92Ð°Ð´Ð¸Ð¼', 'htc desire x')
# ('Ð\x92Ð°Ð´Ð¸Ð¼', 'lenovo a1000 dual sim 4 mobile phone')
# ('Ð\x92Ð°Ð´Ð¸Ð¼', 'lg optimus g')
# ('Ð\x92Ð°Ð´Ð¸Ð¼', 'samsung galaxy note 5 sm n920f')
# ('Ð\x90Ñ\x80Ñ\x82Ñ\x91Ð¼', 'apple iphone 5s')
# ('Ð\x90Ñ\x80Ñ\x82Ñ\x91Ð¼', 'apple iphone 7')
# ('Ð\x90Ñ\x80Ñ\x82Ñ\x91Ð¼', 'huawei honor 8')
# ('Ð\x90Ñ\x80Ñ\x82Ñ\x91Ð¼', 'motorola droid milestone')
# ('Ð\x90Ñ\x80Ñ\x82Ñ\x91Ð¼', 'nokia 5230')
# ('Ð\x90Ñ\x80Ñ\x82ÐµÐ¼', 'apple iphone 5s')
# ('Ð\x90Ñ\x80Ñ\x82ÐµÐ¼', 'gigabyte gsmart maya m1')
# ('Ð\x90Ñ\x80Ñ\x82ÐµÐ¼', 'htc m8')
# ('Ð\x90Ñ\x80Ñ\x82ÐµÐ¼', 'nokia c5')
# ('Ð\x90Ñ\x80Ñ\x82ÐµÐ¼', 'samsung galaxy s7 789999')
# ('Ð\x90Ð½Ñ\x82Ð¾Ð½', 'htc desire 310')
# ('Ð\x90Ð½Ñ\x82Ð¾Ð½', 'htc desire x')
# ('Ð\x90Ð½Ñ\x82Ð¾Ð½', 'htc one m7')
# ('Ð\x90Ð½Ñ\x82Ð¾Ð½', 'htc wildfire')
# ('Ð\x90Ð½Ñ\x82Ð¾Ð½', 'lenovo ideaphone a706')
# ('Ð\x90Ð½Ð½Ð°', 'apple iphone 3gs')
# ('Ð\x90Ð½Ð½Ð°', 'huawei ascend p7')
# ('Ð\x90Ð½Ð½Ð°', 'lg gx500')
# ('Ð\x90Ð½Ð½Ð°', 'lg k10')
# ('Ð\x90Ð½Ð½Ð°', 'lg kp500')
# ('Ð\x90Ð½Ð´Ñ\x80ÐµÐ¹', 'apple iphone se')
# ('Ð\x90Ð½Ð´Ñ\x80ÐµÐ¹', 'asus zenfone selfie zd551kl')
# ('Ð\x90Ð½Ð´Ñ\x80ÐµÐ¹', 'htc desire s')
# ('Ð\x90Ð½Ð´Ñ\x80ÐµÐ¹', 'huawei u8150')
# ('Ð\x90Ð½Ð´Ñ\x80ÐµÐ¹', 'lenovo vibe p1m')
# ('Ð\x90Ð½Ð°Ñ\x81Ñ\x82Ð°Ñ\x81Ð¸Ñ\x8f', 'apple iphone 6')
# ('Ð\x90Ð½Ð°Ñ\x81Ñ\x82Ð°Ñ\x81Ð¸Ñ\x8f', 'apple iphone se')
# ('Ð\x90Ð½Ð°Ñ\x81Ñ\x82Ð°Ñ\x81Ð¸Ñ\x8f', 'lenovo ideaphone a706')
# ('Ð\x90Ð½Ð°Ñ\x81Ñ\x82Ð°Ñ\x81Ð¸Ñ\x8f', 'nokia 5230')
# ('Ð\x90Ð½Ð°Ñ\x81Ñ\x82Ð°Ñ\x81Ð¸Ñ\x8f', 'nokia 5800 xpressmusic tube')
# ('Ð\x90Ð»Ð¸Ð½Ð°', 'apple iphone se')
# ('Ð\x90Ð»Ð¸Ð½Ð°', 'huawei honor 3')
# ('Ð\x90Ð»Ð¸Ð½Ð°', 'nokia asha 200')
# ('Ð\x90Ð»Ð¸Ð½Ð°', 'samsung galaxy a3 2016')
# ('Ð\x90Ð»Ð¸Ð½Ð°', 'samsung galaxy ace 3')
# ('Ð\x90Ð»ÐµÐºÑ\x81ÐµÐ¹', 'asus zenfone 2')
# ('Ð\x90Ð»ÐµÐºÑ\x81ÐµÐ¹', 'htc hd7')
# ('Ð\x90Ð»ÐµÐºÑ\x81ÐµÐ¹', 'huawei ascend p6')
# ('Ð\x90Ð»ÐµÐºÑ\x81ÐµÐ¹', 'lenovo p70')
# ('Ð\x90Ð»ÐµÐºÑ\x81ÐµÐ¹', 'lenovo rocstar a319')
# ('Ð\x90Ð»ÐµÐºÑ\x81Ð°Ð½Ð´Ñ\x80', 'apple iphone 6 plus')
# ('Ð\x90Ð»ÐµÐºÑ\x81Ð°Ð½Ð´Ñ\x80', 'apple iphone 6s')
# ('Ð\x90Ð»ÐµÐºÑ\x81Ð°Ð½Ð´Ñ\x80', 'htc gratia')
# ('Ð\x90Ð»ÐµÐºÑ\x81Ð°Ð½Ð´Ñ\x80', 'htc sensation')
# ('Ð\x90Ð»ÐµÐºÑ\x81Ð°Ð½Ð´Ñ\x80', 'huawei ascend y300')
# ('vincenzo', 'doogee t6 pro')
# ('vincenzo', 'doogee voyager2 dg310')
# ('vincenzo', 'huawei ascend y300')
# ('vincenzo', 'lg g4')
# ('vincenzo', 'nokia lumia 630')
# ('victor', 'apple iphone 5s')
# ('victor', 'apple iphone 7')
# ('victor', 'lenovo zuk z1')
# ('victor', 'samsung galaxy s ii')
# ('victor', 'samsung galaxy s3 mini')
# ('vesponethebest', 'nokia 7230')
# ('vesponethebest', 'nokia 9300')
# ('vesponethebest', 'nokia 9500 communicator')
# ('vesponethebest', 'samsung sgh f480')
# ('vesponethebest', 'nokia 8210')
# ('tony', 'apple iphone 5c')
# ('tony', 'archos 50 platinum')
# ('tony', 'blu advance 4 0 l2')
# ('tony', 'blu studio 6 0')
# ('tony', 'lg l40 dual d170 d175')
# ('thomas', 'cubot p9')
# ('thomas', 'doro phoneeasy 612')
# ('thomas', 'motorola razr i')
# ('thomas', 'motorola razr v3i')
# ('thomas', 'samsung galaxy a3')
# ('streghe_1965', 'apple iphone 3gs')
# ('streghe_1965', 'lg km570')
# ('streghe_1965', 'apple iphone 6s plus')
# ('streghe_1965', 'blackberry curve 9220')
# ('streghe_1965', 'lg optimus l3 e405')
# ('stefano', 'alcatel one touch pop c1')
# ('stefano', 'alcatel onetouch pop c9')
# ('stefano', 'alcatel ot 991d')
# ('stefano', 'htc one xplus')
# ('stefano', 'huawei ascend honor 3c')
# ('simone', 'asus ze550kl')
# ('simone', 'blackberry q5')
# ('simone', 'google nexus 6')
# ('simone', 'huawei p8 lite')
# ('simone', 'lg g3 d855 657484')
# ('silvia', 'alcatel idol 3 5 5 6045y')
# ('silvia', 'asus zenfone max zc550kl')
# ('silvia', 'blackberry q5')
# ('silvia', 'cubot x9')
# ('silvia', 'samsung galaxy note 2')
# ('sergio', 'apple iphone 4s')
# ('sergio', 'apple iphone 6s')
# ('sergio', 'asus ze550kl')
# ('sergio', 'huawei ascend g750')
# ('sergio', 'huawei ascend p7')
# ('schreef', 'apple iphone 5s')
# ('schreef', 'apple iphone 6')
# ('schreef', 'apple iphone 6 plus')
# ('schreef', 'apple iphone 6s')
# ('schreef', 'apple iphone 6s plus')
# ('sara', 'blackberry curve 9380')
# ('sara', 'huawei p9 lite')
# ('sara', 'lg g2 594708')
# ('sara', 'lg g4')
# ('sara', 'microsoft lumia 532')
# ('sandra', 'cubot s222')
# ('sandra', 'huawei ascend y530')
# ('sandra', 'meizu m2 note')
# ('sandra', 'microsoft lumia 950')
# ('sandra', 'nokia x3')
# ('sam', 'apple iphone 6 plus')
# ('sam', 'htc explorer')
# ('sam', 'microsoft lumia 640 dual sim')
# ('sam', 'microsoft lumia 950 xl')
# ('sam', 'oneplus two')
# ('salvatore', 'alcatel onetouch pop 2')
# ('salvatore', 'huawei y6')
# ('salvatore', 'lg g2 594708')
# ('salvatore', 'lg k4')
# ('salvatore', 'motorola moto g')
# ('roberto', 'apple iphone 4')
# ('roberto', 'apple iphone 4s')
# ('roberto', 'apple iphone 5s')
# ('roberto', 'apple iphone 7 plus')
# ('roberto', 'asus ze550kl')
# ('robert', 'apple iphone')
# ('robert', 'blackberry classic')
# ('robert', 'blackberry q10')
# ('robert', 'blu vivo xl')
# ('robert', 'casio hitachi c771')
# ('peter', 'htc evo 3d')
# ('peter', 'htc sensation xe')
# ('peter', 'samsung galaxy note 2')
# ('peter', 'sony xperia e1')
# ('peter', 'huawei p8 lite')
# ('pedro', 'blackberry curve 8520')
# ('pedro', 'htc evo 3d')
# ('pedro', 'htc m8')
# ('pedro', 'htc sensation xe')
# ('pedro', 'lg p880 optimus 4x hd')
# ('paul', 'blackberry passport')
# ('paul', 'blu win jr')
# ('paul', 'cubot c9w')
# ('paul', 'hp slate 6')
# ('paul', 'huawei honor 4x')
# ('patrick', 'archos 50 platinum')
# ('patrick', 'huawei honor 8')
# ('patrick', 'nokia lumia 930')
# ('patrick', 'samsung galaxy s7 789999')
# ('patrick', 'huawei p8 lite')
# ('patricia', 'huawei ascend y530')
# ('patricia', 'samsung nexus s')
# ('patricia', 'cubot x12')
# ('patricia', 'lenovo a816')
# ('patricia', 'nokia 5200')
# ('paolo', 'alcatel one touch idol 6030d')
# ('paolo', 'asus ze500kl')
# ('paolo', 'asus zenfone 2')
# ('paolo', 'asus zenfone 3 max')
# ('paolo', 'google nexus 5x h791')
# ('pablo', 'acer liquid jade z')
# ('pablo', 'huawei honor 6')
# ('pablo', 'lg l70')
# ('pablo', 'samsung galaxy core prime')
# ('pablo', 'sony xperia m4')
# ('oscar', 'apple iphone 5')
# ('oscar', 'meizu m2 note')
# ('oscar', 'motorola moto g4')
# ('oscar', 'nokia lumia 720')
# ('oscar', 'samsung galaxy s7 edge')
# ('narn3049', 'apple iphone 3g')
# ('narn3049', 'blackberry curve 8310')
# ('narn3049', 'blackberry torch 9800')
# ('narn3049', 'lg env2')
# ('narn3049', 'lg rumor2')
# ('mrgreg', 'nokia 101')
# ('mrgreg', 'nokia 105')
# ('mrgreg', 'nokia x2 02')
# ('mrgreg', 'nokia x7')
# ('mrgreg', 'sony ericsson xperia x10 mini pro')
# ('monica', 'huawei p8 lite')
# ('monica', 'lg optimus g pro')
# ('monica', 'samsung galaxy core plus')
# ('monica', 'sony xperia l')
# ('monica', 'samsung galaxy s3 mini')
# ('mike', 'casio g zone ravine 2')
# ('mike', 'doogee y6')
# ('mike', 'htc desire 510')
# ('mike', 'huawei p8 lite')
# ('mike', 'lg vx 8100')
# ('michele', 'alcatel onetouch pop 3 5015d')
# ('michele', 'apple iphone 5c')
# ('michele', 'doogee x5')
# ('michele', 'huawei p8 lite')
# ('michele', 'motorola moto x play')
# ('michael', 'alcatel idol 3 5 5 6045y')
# ('michael', 'blackberry z30')
# ('michael', 'htc desire 816')
# ('michael', 'huawei p9 lite')
# ('michael', 'nokia lumia 635')
# ('max', 'asus zenfone 3')
# ('max', 'huawei ascend honor 3c')
# ('max', 'lg g2 594708')
# ('max', 'microsoft lumia 532')
# ('max', 'microsoft lumia 640 dual sim')
# ('mauro', 'huawei p8')
# ('mauro', 'lg g3 d855 657484')
# ('mauro', 'lg h410')
# ('mauro', 'motorola defyplus')
# ('mauro', 'motorola moto g')
# ('maurizio', 'asus zenfone 2')
# ('maurizio', 'blackview bv5000')
# ('maurizio', 'huawei honor 7')
# ('maurizio', 'huawei p8 lite')
# ('maurizio', 'microsoft lumia 640 xl')
# ('matteo', 'acer liquid e700')
# ('matteo', 'alcatel onetouch pop 3 5015d')
# ('matteo', 'apple iphone 4s')
# ('matteo', 'blackberry q10')
# ('matteo', 'doogee voyager2 dg310')
# ('massimo', 'alcatel one touch pop c7 7041d')
# ('massimo', 'alcatel ot 991d')
# ('massimo', 'blackview bv6000')
# ('massimo', 'huawei ascend y330')
# ('massimo', 'huawei g610')
# ('martin', 'blackberry z30')
# ('martin', 'cubot x6')
# ('martin', 'htc one mini')
# ('martin', 'lg g flex 2')
# ('martin', 'nokia 6280')
# ('mark', 'amazon fire phone')
# ('mark', 'apple iphone se')
# ('mark', 'blu studio 6 0')
# ('mark', 'htc one m7')
# ('mark', 'huawei ascend mate 7')
# ('mario', 'apple iphone 5')
# ('mario', 'blackberry passport')
# ('mario', 'htc one mini')
# ('mario', 'meizu m2 note')
# ('mario', 'nokia asha 501')
# ('maria', 'alcatel ot 991d')
# ('maria', 'apple iphone 5')
# ('maria', 'blackberry curve 8310')
# ('maria', 'blackberry torch 9800')
# ('maria', 'cubot x17')
# ('marco', 'apple iphone 6')
# ('marco', 'elephone p6000 pro')
# ('marco', 'elephone s7')
# ('marco', 'huawei ascend g620s')
# ('marco', 'huawei honor 4x')
# ('manuel', 'acer liquid e2')
# ('manuel', 'motorola moto e')
# ('manuel', 'motorola moto g')
# ('manuel', 'samsung galaxy ace 3')
# ('manuel', 'apple iphone 4s')
# ('luis', 'blackberry pearl 9100')
# ('luis', 'htc one m9 plus')
# ('luis', 'huawei ascend p6')
# ('luis', 'huawei g8')
# ('luis', 'lg g2 594708')
# ('luigi', 'apple iphone 5s')
# ('luigi', 'apple iphone 6')
# ('luigi', 'asus zenfone 2')
# ('luigi', 'cubot s222')
# ('luigi', 'huawei ascend g510')
# ('luca', 'asus ze500kl')
# ('luca', 'blackview bv6000')
# ('luca', 'elephone p8000')
# ('luca', 'htc desire 500')
# ('luca', 'huawei honor 7')
# ('lorenzo', 'huawei honor 6')
# ('lorenzo', 'huawei p8 lite')
# ('lorenzo', 'lg optimus l5 e610')
# ('lorenzo', 'motorola moto g')
# ('lorenzo', 'samsung galaxy note iii')
# ('laura', 'google nexus 6')
# ('laura', 'htc desire x')
# ('laura', 'huawei ascend p7')
# ('laura', 'nokia lumia 635')
# ('laura', 'nokia lumia 720')
# ('lahr2006', 'apple iphone 6')
# ('lahr2006', 'nokia asha 311')
# ('lahr2006', 'samsung galaxy s iii')
# ('lahr2006', 'nokia 100')
# ('lahr2006', 'nokia x6')
# ('kevin', 'cubot gt90')
# ('kevin', 'cubot p6')
# ('kevin', 'htc 8x')
# ('kevin', 'lg g4')
# ('kevin', 'huawei ascend mate 7')
# ('juan', 'alcatel onetouch 20 04')
# ('juan', 'bq aquaris e4 5')
# ('juan', 'elephone p7000')
# ('juan', 'huawei p8 lite')
# ('juan', 'lg optimus l9 ii')
# ('jose', 'blackberry z10')
# ('jose', 'cubot note s')
# ('jose', 'elephone p6000 pro')
# ('jose', 'htc sensation')
# ('jose', 'huawei p8')
# ('jorge', 'bq aquaris e5')
# ('jorge', 'htc desire 500')
# ('jorge', 'nokia lumia 735')
# ('jorge', 'samsung captivate glide')
# ('jorge', 'samsung galaxy s7 edge')
# ('john', 'apple iphone 5')
# ('john', 'apple iphone 6')
# ('john', 'apple iphone se')
# ('john', 'htc desire 310')
# ('john', 'nokia lumia 1520')
# ('joe', 'apple iphone 3gs')
# ('joe', 'lenovo vibe k4 note')
# ('joe', 'lg google nexus 5')
# ('joe', 'motorola moto g')
# ('joe', 'motorola xt1225')
# ('jesus', 'apple iphone 5')
# ('jesus', 'doogee dg800')
# ('jesus', 'htc m8')
# ('jesus', 'samsung galaxy j7')
# ('jesus', 'samsung solstice sgh a887')
# ('javier', 'apple iphone se')
# ('javier', 'doogee x5 pro')
# ('javier', 'huawei honor 6')
# ('javier', 'huawei p8 lite')
# ('javier', 'lg g3 d855 657484')
# ('ivan', 'apple iphone 5s')
# ('ivan', 'cubot p6')
# ('ivan', 'huawei ascend mate 7')
# ('ivan', 'huawei p8')
# ('ivan', 'huawei p8 lite')
# ('iceblu_78', 'htc m8')
# ('iceblu_78', 'nokia lumia 1020')
# ('iceblu_78', 'samsung galaxy s5')
# ('iceblu_78', 'sony xperia z 504642')
# ('iceblu_78', 'sony xperia z ultra')
# ('giuseppe', 'alcatel one touch 1010d')
# ('giuseppe', 'alcatel one touch pop c5 5036d')
# ('giuseppe', 'alcatel onetouch 20 04')
# ('giuseppe', 'alcatel ot 282')
# ('giuseppe', 'apple iphone se')
# ('giovanni', 'apple iphone 6')
# ('giovanni', 'asus zenfone 2 ze551ml')
# ('giovanni', 'huawei g610')
# ('giovanni', 'huawei p8 lite')
# ('giovanni', 'huawei p9 lite')
# ('giorgio', 'alcatel one touch idol 6030d')
# ('giorgio', 'huawei ascend g7')
# ('giorgio', 'huawei ascend mate 7')
# ('giorgio', 'microsoft lumia 640 dual sim')
# ('giorgio', 'motorola moto g')
# ('gabberino93', 'apple iphone 4s')
# ('gabberino93', 'apple iphone 6')
# ('gabberino93', 'htc one sv')
# ('gabberino93', 'lg e900 optimus 7')
# ('gabberino93', 'nokia 100')
# ('frank', 'apple iphone 5s')
# ('frank', 'blackberry passport')
# ('frank', 'blackberry q10')
# ('frank', 'blackberry z30')
# ('frank', 'htc rhyme')
# ('francisco', 'alcatel one touch pixi 3')
# ('francisco', 'apple iphone 7')
# ('francisco', 'doogee nova y100x')
# ('francisco', 'lg p710 optimus l7 ii')
# ('francisco', 'meizu m2 note')
# ('francesco', 'alcatel ot 991d')
# ('francesco', 'asus zenfone 3')
# ('francesco', 'blackberry classic')
# ('francesco', 'blackview bv6000')
# ('francesco', 'cubot note s')
# ('francesca', 'alcatel one touch pop c5 5036d')
# ('francesca', 'apple iphone 5c')
# ('francesca', 'asus zenfone 2')
# ('francesca', 'huawei g8')
# ('francesca', 'huawei p8 lite')
# ('fernando', 'huawei ascend g510')
# ('fernando', 'huawei honor 6')
# ('fernando', 'samsung galaxy a3 2016')
# ('fernando', 'apple iphone 3gs')
# ('fernando', 'huawei ascend g 300')
# ('fabrizio', 'alcatel one touch idol x plus')
# ('fabrizio', 'cat s30')
# ('fabrizio', 'doogee x5 pro')
# ('fabrizio', 'microsoft lumia 532')
# ('fabrizio', 'motorola moto e')
# ('fabio', 'alcatel onetouch 20 04')
# ('fabio', 'apple iphone 5c')
# ('fabio', 'asus ze550kl')
# ('fabio', 'doogee x5 pro')
# ('fabio', 'htc desire 526g')
# ('eric', 'apple iphone 5s')
# ('eric', 'archos 50 helium')
# ('eric', 'blu studio energy')
# ('eric', 'doogee valencia 2 y100 pro')
# ('eric', 'doogee x5 max pro')
# ('elena', 'huawei ascend g7')
# ('elena', 'lg e450 optimus l5 ii')
# ('elena', 'samsung galaxy ace 3')
# ('elena', 'samsung galaxy grand neo plus gt i9060i')
# ('elena', 'samsung gt i8160')
# ('einer Kundin', 'asus zenfone 3')
# ('einer Kundin', 'huawei nova')
# ('einer Kundin', 'huawei p8 lite 2017')
# ('einer Kundin', 'samsung galaxy s8 plus')
# ('einer Kundin', 'apple iphone 7')
# ('einem Kunden', 'apple iphone 6s plus')
# ('einem Kunden', 'apple iphone 7 plus')
# ('einem Kunden', 'asus zenfone 3')
# ('einem Kunden', 'huawei nova')
# ('einem Kunden', 'huawei p10')
# ('eduardo', 'bq aquaris e5')
# ('eduardo', 'huawei p8 lite')
# ('eduardo', 'lg g3 d855 657484')
# ('eduardo', 'samsung galaxy s ii')
# ('eduardo', 'samsung galaxy s5 neo sm g903f')
# ('e-bit', 'alcatel onetouch pixi 4')
# ('e-bit', 'alcatel onetouch pop 3 5015d')
# ('e-bit', 'apple iphone 6 plus')
# ('e-bit', 'apple iphone 7 plus')
# ('e-bit', 'lg g flex d958')
# ('diego', 'asus zenfone 2')
# ('diego', 'asus zenfone 2 ze551ml')
# ('diego', 'lg g3 d855 657484')
# ('diego', 'lg l70')
# ('diego', 'motorola moto g')
# ('davide', 'apple iphone 6')
# ('davide', 'apple iphone se')
# ('davide', 'cubot x9')
# ('davide', 'elephone p9000')
# ('davide', 'huawei ascend p1')
# ('david', 'apple iphone 4s')
# ('david', 'blu life pure xl')
# ('david', 'doogee x5 pro')
# ('david', 'htc wildfire')
# ('david', 'huawei ascend mate')
# ('daniele', 'cubot s308')
# ('daniele', 'huawei ascend p6')
# ('daniele', 'huawei p8')
# ('daniele', 'huawei p8 lite')
# ('daniele', 'lg g2 594708')
# ('daniel', 'apple iphone 3g')
# ('daniel', 'apple iphone 5s')
# ('daniel', 'apple iphone 6s')
# ('daniel', 'blu studio 5 0')
# ('daniel', 'huawei honor 7')
# ('cristina', 'apple iphone 7')
# ('cristina', 'motorola moto g 753361')
# ('cristina', 'oukitel k4000')
# ('cristina', 'samsung galaxy j3 duos')
# ('cristina', 'samsung galaxy j5')
# ('cristian', 'apple iphone 4s')
# ('cristian', 'cubot s208')
# ('cristian', 'htc one e9')
# ('cristian', 'huawei nova plus')
# ('cristian', 'huawei p9 lite')
# ('claudio', 'alcatel one touch pop c7 7041d')
# ('claudio', 'asus ze550kl')
# ('claudio', 'htc desire 310')
# ('claudio', 'huawei ascend y330')
# ('claudio', 'huawei honor 7')
# ('claudia', 'alcatel one touch pop c1')
# ('claudia', 'asus ze550kl')
# ('claudia', 'asus zenfone 2')
# ('claudia', 'lg l bello')
# ('claudia', 'microsoft lumia 950 xl')
# ('christian', 'apple iphone se')
# ('christian', 'asus ze500kl')
# ('christian', 'huawei ascend mate 7')
# ('christian', 'huawei p8 lite')
# ('christian', 'motorola moto e')
# ('chris', 'asus zenfone 2')
# ('chris', 'huawei honor 7')
# ('chris', 'huawei p9 797082')
# ('chris', 'lg g2 594708')
# ('chris', 'lg spirit c70 h440n')
# ('carlos', 'alcatel onetouch pop 3 5015d')
# ('carlos', 'apple iphone se')
# ('carlos', 'blackberry curve 9380')
# ('carlos', 'htc desire')
# ('carlos', 'huawei ascend g525')
# ('carlo', 'acer liquid z630')
# ('carlo', 'huawei ascend p6')
# ('carlo', 'huawei p8 lite 2017')
# ('carlo', 'huawei p9 lite')
# ('carlo', 'huawei shotx')
# ('bruno', 'acer liquid z630')
# ('bruno', 'asus zenfone 2 ze551ml')
# ('bruno', 'lg gt360')
# ('bruno', 'samsung galaxy s5')
# ('bruno', 'samsung gt e1200')
# ('bob', 'lg g5')
# ('bob', 'motorola moto x')
# ('bob', 'samsung gt e1200')
# ('bob', 'huawei honor 6')
# ('bob', 'huawei p8')
# ('antonio', 'apple iphone 4s')
# ('antonio', 'apple iphone 5c')
# ('antonio', 'apple iphone 5s')
# ('antonio', 'elephone p6000 pro')
# ('antonio', 'htc one s')
# ('anonymous', 'apple iphone 3gs')
# ('anonymous', 'apple iphone 4')
# ('anonymous', 'motorola atrix 2')
# ('anonymous', 'motorola xt1225')
# ('anonymous', 'nokia 2700 classic')
# ('anonym', 'blackberry curve 8520')
# ('anonym', 'blackberry q10')
# ('anonym', 'ericsson t10s')
# ('anonym', 'lg p990')
# ('anonym', 'motorola c115')
# ('anonimo', 'samsung galaxy s iii')
# ('anonimo', 'sony xperia sp')
# ('anonimo', 'samsung galaxy s3 mini')
# ('anonimo', 'meizu m3s')
# ('anonimo', 'doogee voyager2 dg310')
# ('anonieme bezoeker', 'blackberry curve 9380')
# ('anonieme bezoeker', 'blackberry q10')
# ('anonieme bezoeker', 'huawei ascend p7')
# ('anonieme bezoeker', 'samsung galaxy mini 2 s6500')
# ('anonieme bezoeker', 'samsung galaxy s4 active i9295')
# ('anna', 'apple iphone 5c')
# ('anna', 'asus zenfone 3')
# ('anna', 'asus zenfone 5')
# ('anna', 'cubot x12')
# ('anna', 'mysaga c2')
# ('angelo', 'alcatel idol mini 6012')
# ('angelo', 'elephone p8000')
# ('angelo', 'lg g2 594708')
# ('angelo', 'nokia n81')
# ('angelo', 'samsung c3590')
# ('andrea', 'apple iphone 4')
# ('andrea', 'apple iphone 6s')
# ('andrea', 'asus ze500kl')
# ('andrea', 'asus zenfone 3 max')
# ('andrea', 'huawei ascend g525')
# ('ana', 'samsung galaxy j5 4g lte 5 2 inches')
# ('ana', 'sony ericsson xperia active')
# ('ana', 'sony xperia c5 ultra')
# ('ana', 'huawei ascend g510')
# ('ana', 'leagoo lead 6')
# ('alex', 'apple iphone 4s')
# ('alex', 'apple iphone 6')
# ('alex', 'blu dash j')
# ('alex', 'doogee voyager2 dg310')
# ('alex', 'htc evo 4g')
# ('alessandro', 'alcatel onetouch pop c9')
# ('alessandro', 'apple iphone 6s')
# ('alessandro', 'blackberry z30')
# ('alessandro', 'elephone p9000')
# ('alessandro', 'huawei ascend p6')
# ('alberto', 'asus ze550kl')
# ('alberto', 'blu studio 5 5s')
# ('alberto', 'huawei ascend g525')
# ('alberto', 'huawei honor 6')
# ('alberto', 'lg g5')
# ('ZÃ¡kaznÃ\xadk', 'apple iphone 5s')
# ('ZÃ¡kaznÃ\xadk', 'apple iphone 6 plus')
# ('ZÃ¡kaznÃ\xadk', 'asus zenfone go zc500tg')
# ('ZÃ¡kaznÃ\xadk', 'caterpillar b30 cat b30')
# ('ZÃ¡kaznÃ\xadk', 'htc desire 510')
# ('Yvonne', 'apple iphone 5')
# ('Yvonne', 'htc one x')
# ('Yvonne', 'lg cosmos 2')
# ('Yvonne', 'lg g2 594708')
# ('Yvonne', 'lg optimus one p500')
# ('Wolfgang', 'benq siemens s68')
# ('Wolfgang', 'htc one mini')
# ('Wolfgang', 'huawei ascend y300')
# ('Wolfgang', 'lg gd880 mini')
# ('Wolfgang', 'microsoft lumia 640 dual sim')
# ('William', 'apple iphone 5s')
# ('William', 'apple iphone 6s')
# ('William', 'huawei ascend mate 7')
# ('William', 'motorola moto g3')
# ('William', 'oneplus two')
# ('Will', 'htc desire s')
# ('Will', 'htc m8')
# ('Will', 'huawei honor 5x')
# ('Will', 'microsoft lumia 650')
# ('Will', 'motorola moto g')
# ('Wendy', 'htc wildfire s')
# ('Wendy', 'nokia 113')
# ('Wendy', 'samsung galaxy note iii')
# ('Wendy', 'lg rumor touch')
# ('Wendy', 'samsung star 3')
# ('Walter', 'apple iphone 6 plus')
# ('Walter', 'lenovo moto g4 plus')
# ('Walter', 'oneplus x')
# ('Walter', 'samsung galaxy s4 mini gt i9190 gt i9192 dual sim')
# ('Walter', 'samsung galaxy s7 edge')
# ('Vincenzo', 'apple iphone 4s')
# ('Vincenzo', 'apple iphone 6s plus')
# ('Vincenzo', 'blackberry classic')
# ('Vincenzo', 'doogee homtom ht7')
# ('Vincenzo', 'huawei p9 lite')
# ('Vincent', 'huawei p9 lite')
# ('Vincent', 'microsoft lumia 640 xl')
# ('Vincent', 'motorola moto g')
# ('Vincent', 'nokia lumia 635')
# ('Vincent', 'nokia n96')
# ('Victoria', 'blackberry passport')
# ('Victoria', 'doogee x5')
# ('Victoria', 'lg k4')
# ('Victoria', 'nokia 6303i')
# ('Victoria', 'samsung galaxy prevail')
# ('Victor', 'blackberry curve 8520')
# ('Victor', 'blackberry curve 9360')
# ('Victor', 'blu life pure')
# ('Victor', 'cubot gt95')
# ('Victor', 'htc desire')
# ('Vanessa', 'apple iphone 5s')
# ('Vanessa', 'motorola i465')
# ('Vanessa', 'motorola moto e')
# ('Vanessa', 'motorola moto x')
# ('Vanessa', 'samsung galaxy note 2')
# ('Valerio', 'apple iphone 5c')
# ('Valerio', 'htc wildfire')
# ('Valerio', 'motorola moto g')
# ('Valerio', 'samsung ativ s')
# ('Valerio', 'samsung galaxy a5')
# ('Valentina', 'asus ze550kl')
# ('Valentina', 'asus zenfone 2')
# ('Valentina', 'htc inspire 4g')
# ('Valentina', 'huawei ascend p1')
# ('Valentina', 'huawei p9 lite')
# ('Un anonyme', 'motorola moto x style')
# ('Un anonyme', 'nokia 2720 324826')
# ('Un anonyme', 'nokia 6230i')
# ('Un anonyme', 'nokia 8800')
# ('Un anonyme', 'nokia lumia 520')
# ('UK Guest', 'motorola v550')
# ('UK Guest', 'nokia 2650')
# ('UK Guest', 'nokia 3510i')
# ('UK Guest', 'nokia 6100')
# ('UK Guest', 'samsung sgh e600')
# ('Tony', 'apple iphone 5c')
# ('Tony', 'apple iphone 7 plus')
# ('Tony', 'blackberry q10')
# ('Tony', 'google nexus 6p')
# ('Tony', 'htc desire 816')
# ('Toni', 'motorola droid x')
# ('Toni', 'nokia e5')
# ('Toni', 'nokia n9')
# ('Toni', 'samsung c3322')
# ('Toni', 'samsung galaxy s plus')
# ('Tommy', 'apple iphone 6 plus')
# ('Tommy', 'hp veer')
# ('Tommy', 'htc one m7')
# ('Tommy', 'motorola moto g')
# ('Tommy', 'nokia lumia 925')
# ('Tom', 'blackberry bold 9900')
# ('Tom', 'blackberry classic')
# ('Tom', 'blackberry z10')
# ('Tom', 'blu vivo air')
# ('Tom', 'htc one s')
# ('Tobias', 'apple iphone 6')
# ('Tobias', 'lg g2 594708')
# ('Tobias', 'motorola razr v3')
# ('Tobias', 'huawei mate 9')
# ('Tobias', 'sony ericsson p900')
# ('Tina', 'asus zenfone 2 ze551ml')
# ('Tina', 'blu studio energy')
# ('Tina', 'samsung galaxy ace s5830')
# ('Tina', 'samsung galaxy s4 mini gt i9190 gt i9192 dual sim')
# ('Tina', 'samsung galaxy s7 edge')
# ('Tim', 'apple iphone 5')
# ('Tim', 'apple iphone 5c')
# ('Tim', 'apple iphone 6s')
# ('Tim', 'apple iphone 7 plus')
# ('Tim', 'google nexus 5x h791')
# ('Thomas', 'alcatel one touch 992d')
# ('Thomas', 'apple iphone se')
# ('Thomas', 'asus zenfone go zc500tg')
# ('Thomas', 'blackberry curve 9320')
# ('Thomas', 'blackberry torch 9800')
# ('Terry', 'apple iphone 6')
# ('Terry', 'microsoft lumia 640 xl')
# ('Terry', 'motorola xt1225')
# ('Terry', 'samsung galaxy note 4')
# ('Terry', 'samsung gt e1270')
# ('T', 'motorola xt1225')
# ('T', 'samsung galaxy s5')
# ('T', 'samsung galaxy s7 edge')
# ('T', 'sony xperia sp')
# ('T', 'xiaomi mi max')
# ('Sven', 'huawei p8')
# ('Sven', 'nokia lumia 830')
# ('Sven', 'nokia x6')
# ('Sven', 'samsung e1080')
# ('Sven', 'samsung e1182')
# ('Susan', 'lg cosmos touch')
# ('Susan', 'motorola moto g')
# ('Susan', 'motorola moto g3')
# ('Susan', 'samsung galaxy s iii')
# ('Susan', 'samsung galaxy s4 mini gt i9190 gt i9192 dual sim')
# ('Sunny', 'huawei ascend y300')
# ('Sunny', 'lg gw300')
# ('Sunny', 'lg kg800')
# ('Sunny', 'motorola w376')
# ('Sunny', 'samsung galaxy note 2')
# ('Steven', 'apple iphone 5s')
# ('Steven', 'apple iphone 7')
# ('Steven', 'google nexus 5x h791')
# ('Steven', 'htc evo 4g')
# ('Steven', 'huawei p8')
# ('Steve', 'apple iphone 5s')
# ('Steve', 'apple iphone 7')
# ('Steve', 'apple iphone se')
# ('Steve', 'blackberry q10')
# ('Steve', 'google nexus 5x h791')
# ('Stephen', 'alcatel onetouch pixi 4')
# ('Stephen', 'huawei honor 5x')
# ('Stephen', 'lg vn530')
# ('Stephen', 'motorola xt1225')
# ('Stephen', 'samsung galaxy note 4')
# ('Stephanie', 'htc one e8')
# ('Stephanie', 'huawei ascend p7')
# ('Stephanie', 'huawei mate s')
# ('Stephanie', 'huawei p8 lite')
# ('Stephanie', 'samsung galaxy j7 2016')
# ('Stephan', 'apple iphone 5s')
# ('Stephan', 'huawei honor')
# ('Stephan', 'huawei p8')
# ('Stephan', 'nokia asha 311')
# ('Stephan', 'samsung c3520')
# ('Stefano', 'alcatel onetouch 20 04')
# ('Stefano', 'apple iphone 7')
# ('Stefano', 'asus zenfone 3 max')
# ('Stefano', 'asus zenfone 6')
# ('Stefano', 'asus zenfone max zc550kl')
# ('Stefania', 'asus zenfone selfie zd551kl')
# ('Stefania', 'blackberry q10')
# ('Stefania', 'htc m8')
# ('Stefania', 'microsoft lumia 435')
# ('Stefania', 'nokia lumia 735')
# ('Stefan', 'htc legend')
# ('Stefan', 'huawei ascend y300')
# ('Stefan', 'huawei honor 7')
# ('Stefan', 'lg vx 8550 chocolate')
# ('Stefan', 'microsoft lumia 535')
# ('Sophie', 'apple iphone 4')
# ('Sophie', 'google nexus 5x h791')
# ('Sophie', 'motorola rival a455')
# ('Sophie', 'nokia 3510')
# ('Sophie', 'samsung galaxy s6')
# ('Sonia', 'huawei ascend y300')
# ('Sonia', 'microsoft lumia 640 xl')
# ('Sonia', 'samsung galaxy grand prime')
# ('Sonia', 'samsung galaxy note 2')
# ('Sonia', 'samsung galaxy s7 edge')
# ('Simone', 'apple iphone 6s')
# ('Simone', 'asus zenfone 2')
# ('Simone', 'asus zenfone 5')
# ('Simone', 'huawei ascend p7 mini')
# ('Simone', 'huawei honor 6x')
# ('Simon', 'apple iphone 6 plus')
# ('Simon', 'asus zenfone 3')
# ('Simon', 'cat s30')
# ('Simon', 'huawei ascend y300')
# ('Simon', 'motorola moto g')
# ('Silvia', 'asus zenfone 3')
# ('Silvia', 'asus zenfone selfie zd551kl')
# ('Silvia', 'cubot x15')
# ('Silvia', 'doogee t6 pro')
# ('Silvia', 'htc m8')
# ('Sergio', 'apple iphone 5')
# ('Sergio', 'asus ze500kl')
# ('Sergio', 'bq aquaris e4 5')
# ('Sergio', 'doogee x5')
# ('Sergio', 'google nexus 6')
# ('Sebastian', 'apple iphone 6s plus')
# ('Sebastian', 'htc hd2')
# ('Sebastian', 'htc one mini')
# ('Sebastian', 'lg optimus l7')
# ('Sebastian', 'meizu m2 note')
# ('Sean', 'alcatel idol 3 5 5 6045y')
# ('Sean', 'blu studio 5 3')
# ('Sean', 'cubot x6')
# ('Sean', 'elephone p9000')
# ('Sean', 'htc one sv')
# ('Scott', 'apple iphone 5s')
# ('Scott', 'blu win hd')
# ('Scott', 'htc one e8')
# ('Scott', 'htc one m7')
# ('Scott', 'motorola moto g')
# ('Sarah', 'apple iphone 4')
# ('Sarah', 'apple iphone 6s plus')
# ('Sarah', 'apple iphone se')
# ('Sarah', 'blu studio 5 0')
# ('Sarah', 'blu studio x plus')
# ('Sara', 'asus zenfone 2 ze551ml')
# ('Sara', 'huawei ascend g525')
# ('Sara', 'huawei ascend p1')
# ('Sara', 'huawei ascend p7')
# ('Sara', 'huawei honor 6')
# ('Santiago', 'huawei honor 3')
# ('Santiago', 'lenovo golden warrior s8')
# ('Santiago', 'nokia lumia 1520')
# ('Santiago', 'nokia lumia 925')
# ('Santiago', 'sony ericsson xperia ray')
# ('Sandy', 'apple iphone 5s')
# ('Sandy', 'htc legend')
# ('Sandy', 'lg mytouch q')
# ('Sandy', 'motorola moto g4')
# ('Sandy', 'nokia x6')
# ('Sandro', 'microsoft lumia 640 dual sim')
# ('Sandro', 'motorola moto e')
# ('Sandro', 'motorola moto g')
# ('Sandro', 'samsung galaxy s7 789999')
# ('Sandro', 'samsung galaxy ace s5830')
# ('Sandra', 'alcatel one touch 995')
# ('Sandra', 'apple iphone 5c')
# ('Sandra', 'apple iphone 5s')
# ('Sandra', 'apple iphone 6s plus')
# ('Sandra', 'blackberry z10')
# ('Samuel', 'apple iphone 6s')
# ('Samuel', 'apple iphone 7')
# ('Samuel', 'blackview bv5000')
# ('Samuel', 'huawei ascend mate 7')
# ('Samuel', 'huawei honor 6')
# ('Samantha', 'apple iphone 5')
# ('Samantha', 'asus zenfone 2')
# ('Samantha', 'blackberry z10')
# ('Samantha', 'blu d670u')
# ('Samantha', 'lg g flex d958')
# ('Sam', 'apple iphone 5s')
# ('Sam', 'apple iphone 7')
# ('Sam', 'blackberry passport')
# ('Sam', 'htc inspire 4g')
# ('Sam', 'huawei honor 5x')
# ('Salvatore', 'acer liquid z630')
# ('Salvatore', 'alcatel one touch pixi 3')
# ('Salvatore', 'apple iphone 5')
# ('Salvatore', 'apple iphone 7')
# ('Salvatore', 'elephone p7000')
# ('Sabrina', 'google nexus 6')
# ('Sabrina', 'htc desire c golf wildfire c')
# ('Sabrina', 'huawei honor 8')
# ('Sabrina', 'huawei p8 lite')
# ('Sabrina', 'microsoft lumia 640 dual sim')
# ('Sabine', 'asus ze550kl')
# ('Sabine', 'samsung e1100')
# ('Sabine', 'samsung galaxy s3 mini')
# ('Sabine', 'samsung galaxy s5')
# ('Sabine', 'samsung wave y')
# ('S', 'asus zenfone 3')
# ('S', 'huawei p8 lite')
# ('S', 'motorola moto g4')
# ('S', 'nokia lumia 635')
# ('S', 'samsung galaxy j3 duos')
# ('Ryan', 'apple iphone 5c')
# ('Ryan', 'caterpillar s60')
# ('Ryan', 'huawei honor 6')
# ('Ryan', 'nokia lumia 620')
# ('Ryan', 'samsung galaxy ace s5830')
# ('Ruben', 'asus ze500kl')
# ('Ruben', 'cubot note s')
# ('Ruben', 'lg g3 d855 657484')
# ('Ruben', 'lg g5')
# ('Ruben', 'motorola moto g4')
# ('Roy', 'apple iphone 5s')
# ('Roy', 'apple iphone 6s')
# ('Roy', 'samsung e1150')
# ('Roy', 'samsung galaxy a3')
# ('Roy', 'samsung galaxy note iii')
# ('Ronald', 'motorola moto g')
# ('Ronald', 'samsung galaxy ace plus')
# ('Ronald', 'samsung galaxy note 2')
# ('Ronald', 'samsung galaxy s3 mini')
# ('Ronald', 'lg g4')
# ('Ron', 'apple iphone 4')
# ('Ron', 'apple iphone 5s')
# ('Ron', 'apple iphone 6')
# ('Ron', 'caterpillar s40')
# ('Ron', 'huawei honor 8')
# ('Roman', 'huawei honor 6')
# ('Roman', 'huawei p8')
# ('Roman', 'lg eclipse 4g lte')
# ('Roman', 'lg optimus l7')
# ('Roman', 'motorola moto g4')
# ('Roland', 'alcatel one touch 992d')
# ('Roland', 'apple iphone 3g')
# ('Roland', 'apple iphone 4s')
# ('Roland', 'binatone the brick')
# ('Roland', 'htc one s')
# ('Rohit', 'asus zenfone max zc550kl')
# ('Rohit', 'oneplus one 64gb')
# ('Rohit', 'sony xperia sp')
# ('Rohit', 'xiaomi mi 4i')
# ('Rohit', 'htc one m7')
# ('Roger', 'blu q170t')
# ('Roger', 'lg g4')
# ('Roger', 'nokia lumia 1520')
# ('Roger', 'sony xperia z5')
# ('Roger', 'blu win jr')
# ('Rodrigo', 'asus zenfone 2 ze551ml')
# ('Rodrigo', 'asus zenfone 3')
# ('Rodrigo', 'bq aquaris e4 5')
# ('Rodrigo', 'motorola moto x')
# ('Rodrigo', 'apple iphone 5s')
# ('Robin', 'alcatel ot 991d')
# ('Robin', 'huawei honor 8')
# ('Robin', 'lg g flex d958')
# ('Robin', 'samsung galaxy a3 2016')
# ('Robin', 'samsung galaxy s6')
# ('Roberto', 'acer liquid e2')
# ('Roberto', 'apple iphone 4')
# ('Roberto', 'asus ze550kl')
# ('Roberto', 'asus zenfone 2 laser ze500kl')
# ('Roberto', 'asus zenfone 2 ze551ml')
# ('Roberta', 'apple iphone 5s')
# ('Roberta', 'blackberry curve 9320')
# ('Roberta', 'huawei p9 lite')
# ('Roberta', 'sony xperia t')
# ('Roberta', 'wiko fever')
# ('Robert', 'blackberry classic')
# ('Robert', 'blackberry curve 9320')
# ('Robert', 'htc 8x')
# ('Robert', 'htc legend')
# ('Robert', 'huawei ascend p6')
# ('Rob', 'alcatel one touch pixi 3')
# ('Rob', 'apple iphone 4s')
# ('Rob', 'apple iphone 6')
# ('Rob', 'apple iphone 7')
# ('Rob', 'blackberry z10')
# ('Rick', 'alcatel idol 3 5 5 6045y')
# ('Rick', 'apple iphone 7')
# ('Rick', 'htc evo 3d')
# ('Rick', 'motorola droid 425280')
# ('Rick', 'motorola moto g3')
# ('Richard', 'alcatel onetouch pixi 4')
# ('Richard', 'apple iphone 5c')
# ('Richard', 'apple iphone 6s')
# ('Richard', 'doogee x6 pro')
# ('Richard', 'doro liberto 820')
# ('Riccardo', 'apple iphone 6s plus')
# ('Riccardo', 'asus ze550kl')
# ('Riccardo', 'blackberry bold 9790')
# ('Riccardo', 'blackberry q10')
# ('Riccardo', 'caterpillar s60')
# ('Ricardo', 'lenovo k3 note')
# ('Ricardo', 'motorola moto x force 32gb')
# ('Ricardo', 'nokia lumia 520')
# ('Ricardo', 'samsung galaxy j7 2016')
# ('Ricardo', 'samsung galaxy s iii')
# ('Rene', 'huawei ascend y530')
# ('Rene', 'microsoft lumia 550')
# ('Rene', 'nokia c3')
# ('Rene', 'nokia lumia 720')
# ('Rene', 'samsung galaxy s duos s7562')
# ('Renato', 'asus zenfone 3')
# ('Renato', 'cubot note s')
# ('Renato', 'lg v20 h990')
# ('Renato', 'microsoft lumia 532')
# ('Renato', 'motorola moto g')
# ('Rebecca', 'apple iphone 5s')
# ('Rebecca', 'apple iphone 6')
# ('Rebecca', 'htc one s')
# ('Rebecca', 'huawei ascend p6')
# ('Rebecca', 'motorola moto x')
# ('Ray', 'huawei honor 8')
# ('Ray', 'lg g3 d855 657484')
# ('Ray', 'lg g5')
# ('Ray', 'pantech crossover')
# ('Ray', 'samsung galaxy note 2')
# ('Ravi', 'blackberry curve 9320')
# ('Ravi', 'google pixel')
# ('Ravi', 'apple iphone 5s')
# ('Ravi', 'asus zenfone max zc550kl')
# ('Ravi', 'motorola moto g3')
# ('Raul', 'huawei ascend mate 7')
# ('Raul', 'huawei honor 7')
# ('Raul', 'huawei p8 lite')
# ('Raul', 'lg google nexus 5')
# ('Raul', 'motorola moto e')
# ('Raquel', 'lg a275')
# ('Raquel', 'motorola moto g4')
# ('Raquel', 'samsung galaxy core plus')
# ('Raquel', 'samsung galaxy g130 young 2')
# ('Raquel', 'samsung sm g531h')
# ('Ralf', 'lg secret kf750')
# ('Ralf', 'nokia 6303i')
# ('Ralf', 'oukitel k10000')
# ('Ralf', 'lg ke850 prada')
# ('Ralf', 'samsung galaxy gio s5660')
# ('Rajesh', 'motorola moto e 2 lte')
# ('Rajesh', 'nokia c3')
# ('Rajesh', 'nokia x2')
# ('Rajesh', 'samsung galaxy j7 2016')
# ('Rajesh', 'samsung galaxy note 3 neo 4g n7505')
# ('Raj', 'apple iphone 5s')
# ('Raj', 'blu win hd')
# ('Raj', 'lenovo vibe k4 note')
# ('Raj', 'lg nexus 4')
# ('Raj', 'oneplus 3t')
# ('Rahul', 'alcatel idol 3 5 5 6045y')
# ('Rahul', 'asus zenfone 2 laser ze601kl')
# ('Rahul', 'blackberry dtek60')
# ('Rahul', 'lenovo vibe k4 note')
# ('Rahul', 'oneplus 3')
# ('Raffaele', 'asus zenfone 3')
# ('Raffaele', 'htc desire 500')
# ('Raffaele', 'huawei ascend g700')
# ('Raffaele', 'huawei ascend p1')
# ('Raffaele', 'huawei p8 lite')
# ('Rafael', 'asus zenfone 3')
# ('Rafael', 'blackberry passport')
# ('Rafael', 'bq aquaris e5')
# ('Rafael', 'elephone p6000 pro')
# ('Rafael', 'samsung galaxy s plus')
# ('Rachel', 'apple iphone 4s')
# ('Rachel', 'apple iphone 5')
# ('Rachel', 'apple iphone 6')
# ('Rachel', 'apple iphone 7')
# ('Rachel', 'asus zenfone max zc550kl')
# ('Qantas', 'htc one m7')
# ('Qantas', 'htc one xplus')
# ('Qantas', 'lg kg800')
# ('Qantas', 'nokia lumia 1020')
# ('Qantas', 'samsung omnia 7')
# ('Puneet Sharma', 'apple iphone 4s')
# ('Puneet Sharma', 'karbonn titanium octane')
# ('Puneet Sharma', 'karbonn titanium x')
# ('Puneet Sharma', 'micromax a240')
# ('Puneet Sharma', 'micromax canvas turbo a250')
# ('Pseudonym', 'blackberry bold 9900')
# ('Pseudonym', 'blackberry classic')
# ('Pseudonym', 'htc chacha')
# ('Pseudonym', 'htc one m7')
# ('Pseudonym', 'motorola moto g')
# ('Praveen', 'nokia lumia 640 lte')
# ('Praveen', 'oneplus one 64gb')
# ('Praveen', 'samsung galaxy j7')
# ('Praveen', 'xiaomi mi max')
# ('Praveen', 'oneplus 3')
# ('Pietro', 'huawei ascend g7')
# ('Pietro', 'huawei p9 lite')
# ('Pietro', 'huawei p9 plus')
# ('Pietro', 'lg g2 594708')
# ('Pietro', 'motorola moto g')
# ('Pierre', 'apple iphone 6')
# ('Pierre', 'lg g3 d855 657484')
# ('Pierre', 'samsung galaxy note')
# ('Pierre', 'samsung wave s8500')
# ('Pierre', 'sony xperia z3 compact')
# ('Philippe', 'blackberry q10')
# ('Philippe', 'huawei ascend p7')
# ('Philippe', 'motorola moto g')
# ('Philippe', 'nokia 220')
# ('Philippe', 'nokia lumia 930')
# ('Philipp', 'apple iphone 6')
# ('Philipp', 'asus zenfone 2 ze551ml')
# ('Philipp', 'doro phoneeasy 409 s gsm')
# ('Philipp', 'nokia e6')
# ('Philipp', 'nokia lumia 635')
# ('Phil', 'htc one m9')
# ('Phil', 'huawei y6')
# ('Phil', 'nokia lumia 610')
# ('Phil', 'nokia lumia 635')
# ('Phil', 'nokia lumia 928')
# ('Petra', 'cubot x15')
# ('Petra', 'huawei ascend p6')
# ('Petra', 'microsoft lumia 640 dual sim')
# ('Petra', 'nokia 100')
# ('Petra', 'nokia 3110 classic')
# ('Peter', 'acer liquid z3 duo')
# ('Peter', 'apple iphone 5s')
# ('Peter', 'apple iphone 7')
# ('Peter', 'blackberry z30')
# ('Peter', 'htc 7 mozart')
# ('Pete', 'apple iphone 7 plus')
# ('Pete', 'doogee x5 max pro')
# ('Pete', 'samsung c5212')
# ('Pete', 'samsung galaxy j7 prime')
# ('Pete', 'samsung galaxy y s5360')
# ('Pen Name', 'apple iphone 4')
# ('Pen Name', 'apple iphone 6')
# ('Pen Name', 'blackberry z10')
# ('Pen Name', 'blu vivo air')
# ('Pen Name', 'kyocera hydro edge')
# ('Pedro', 'alcatel one touch 997d ot 997d')
# ('Pedro', 'apple iphone 6')
# ('Pedro', 'asus zenfone 6')
# ('Pedro', 'blackberry q10')
# ('Pedro', 'cubot note s')
# ('Paulo', 'alcatel onetouch pixi 4')
# ('Paulo', 'apple iphone se')
# ('Paulo', 'asus zc551kl')
# ('Paulo', 'asus zenfone 2 ze551ml')
# ('Paulo', 'nokia lumia 630')
# ('Paula', 'apple iphone 6s')
# ('Paula', 'doogee dg2014')
# ('Paula', 'htc dream t mobile g1')
# ('Paula', 'motorola moto g')
# ('Paula', 'samsung galaxy note iii')
# ('Paul', 'apple iphone 4s')
# ('Paul', 'apple iphone 5')
# ('Paul', 'apple iphone 5s')
# ('Paul', 'apple iphone 7')
# ('Paul', 'apple iphone se')
# ('Patrick', 'apple iphone 6 plus')
# ('Patrick', 'apple iphone se')
# ('Patrick', 'blackberry 9700')
# ('Patrick', 'blackview bv6000')
# ('Patrick', 'htc desire 601')
# ('Patricia', 'apple iphone 4s')
# ('Patricia', 'apple iphone se')
# ('Patricia', 'asus zenfone 3')
# ('Patricia', 'blu a310a')
# ('Patricia', 'doogee valencia 2 y100 pro')
# ('Pat', 'apple iphone 5')
# ('Pat', 'cubot x15')
# ('Pat', 'htc one m7')
# ('Pat', 'nokia c3')
# ('Pat', 'samsung galaxy s7 edge')
# ('Pasquale', 'doogee voyager2 dg310')
# ('Pasquale', 'huawei ascend mate 7')
# ('Pasquale', 'huawei p8 lite 2017')
# ('Pasquale', 'meizu mx5')
# ('Pasquale', 'microsoft lumia 532')
# ('Pascal', 'htc sensation')
# ('Pascal', 'huawei honor 8')
# ('Pascal', 'lg l fino')
# ('Pascal', 'nokia lumia 735')
# ('Pascal', 'samsung galaxy a3')
# ('Paolo', 'acer liquid z520')
# ('Paolo', 'alcatel onetouch 20 04')
# ('Paolo', 'apple iphone 5s')
# ('Paolo', 'asus zenfone 3')
# ('Paolo', 'asus zenfone 3 max')
# ('Paola', 'asus ze550kl')
# ('Paola', 'asus zenfone go zc500tg')
# ('Paola', 'blu vivo air')
# ('Paola', 'lg g3 d855 657484')
# ('Paola', 'motorola moto e')
# ('Pablo', 'asus zenfone 2 ze551ml')
# ('Pablo', 'doogee dagger dg550')
# ('Pablo', 'huawei ascend p7')
# ('Pablo', 'huawei p8 lite')
# ('Pablo', 'lenovo zuk z1')
# ('Oscar', 'apple iphone 6')
# ('Oscar', 'elephone p8000')
# ('Oscar', 'elephone p9000')
# ('Oscar', 'huawei ideos x5')
# ('Oscar', 'lenovo ideaphone s960')
# ('Omar', 'blackberry curve 8520')
# ('Omar', 'bq aquaris e5')
# ('Omar', 'htc amaze 4g')
# ('Omar', 'motorola moto g')
# ('Omar', 'nokia 7250')
# ('Olivier', 'archos 50 helium')
# ('Olivier', 'asus zenfone 2 ze551ml')
# ('Olivier', 'htc 8x')
# ('Olivier', 'htc one s')
# ('Olivier', 'huawei ascend g620s')
# ('Oliver', 'blackview bv6000')
# ('Oliver', 'cubot note s')
# ('Oliver', 'htc 8x')
# ('Oliver', 'htc one mini')
# ('Oliver', 'nokia e51')
# ('Oks', 'htc 7 mozart')
# ('Oks', 'samsung genoa c3510')
# ('Oks', 'nokia 2100')
# ('Oks', 'nokia 5200')
# ('Oks', 'nokia 5230')
# ('Nina', 'amplicom m5010')
# ('Nina', 'lg t300')
# ('Nina', 'nokia 1208')
# ('Nina', 'nokia 7500 prism')
# ('Nina', 'samsung c260')
# ('Nicole', 'blackberry priv')
# ('Nicole', 'huawei ascend mate 8')
# ('Nicole', 'huawei ascend y330')
# ('Nicole', 'lg t385')
# ('Nicole', 'nokia 6700 slide')
# ('Nicolas', 'apple iphone 6s plus')
# ('Nicolas', 'apple iphone se')
# ('Nicolas', 'asus ze550kl')
# ('Nicolas', 'asus zenfone 3 deluxe')
# ('Nicolas', 'asus zenfone 3 max')
# ('Nicola', 'alcatel ot 903')
# ('Nicola', 'apple iphone 5c')
# ('Nicola', 'apple iphone 7')
# ('Nicola', 'apple iphone 7 plus')
# ('Nicola', 'asus zenfone 3')
# ('Nico', 'asus zenfone 2 laser ze500kl')
# ('Nico', 'oneplus one 64gb')
# ('Nico', 'samsung galaxy core')
# ('Nico', 'samsung galaxy s plus')
# ('Nico', 'samsung galaxy s6')
# ('Nick', 'apple iphone 5c')
# ('Nick', 'apple iphone 5s')
# ('Nick', 'apple iphone 6 plus')
# ('Nick', 'hp ipaq 214')
# ('Nick', 'htc 10')
# ('Nathan', 'asus zenfone 2')
# ('Nathan', 'motorola moto x')
# ('Nathan', 'nokia 107')
# ('Nathan', 'samsung galaxy note 5 sm n920f')
# ('Nathan', 'samsung galaxy s5')
# ('Monica', 'asus zenfone 5')
# ('Monica', 'blackberry bold 9780')
# ('Monica', 'blackberry curve 8520')
# ('Monica', 'blackberry curve 9380')
# ('Monica', 'doogee homtom ht7')
# ('Mirko', 'alcatel idol 3 5 5 6045y')
# ('Mirko', 'asus zenfone 3')
# ('Mirko', 'asus zenfone 3 max')
# ('Mirko', 'huawei p9 lite')
# ('Mirko', 'lg google nexus 5')
# ('Mike', 'apple iphone 5c')
# ('Mike', 'apple iphone 7')
# ('Mike', 'apple iphone se')
# ('Mike', 'asus zc551kl')
# ('Mike', 'blackberry z30')
# ('Miguel', 'apple iphone 4s')
# ('Miguel', 'asus zenfone 2')
# ('Miguel', 'bq aquaris e4 5')
# ('Miguel', 'elephone p6000 pro')
# ('Miguel', 'huawei ascend g510')
# ('Michelle', 'asus zenfone 2 ze551ml')
# ('Michelle', 'blu studio 5 0')
# ('Michelle', 'huawei p8 lite')
# ('Michelle', 'lg g2 594708')
# ...
# ('Charlie', 'blackberry passport')
# ('Charlie', 'cubot x10')
# ('Charlie', 'lg g3 d855 657484')
# ('Charlie', 'samsung b3310')
# ('Charles', 'cubot x6')
# ('Charles', 'huawei ascend mate')
# ('Charles', 'lg cosmos 2')
# ('Charles', 'nokia 108')
# ('Charles', 'samsung galaxy j1 2016 4 5 sm j120')
# ('Cesar', 'huawei ascend y320')
# ('Cesar', 'lg google nexus 5')
# ('Cesar', 'lg l90 d410')
# ('Cesar', 'motorola moto g4')
# ('Cesar', 'nokia n900')
# ('Carol', 'blu dash jr w')
# ('Carol', 'motorola droid 2')
# ('Carol', 'nokia asha 311')
# ('Carol', 'samsung galaxy g130 young 2')
# ('Carol', 'samsung galaxy s3 mini')
# ('Carmen', 'blackberry bold 9900')
# ('Carmen', 'doro phoneeasy 612')
# ('Carmen', 'huawei ascend y330')
# ('Carmen', 'huawei honor 6')
# ('Carmen', 'huawei p8 lite')
# ('Carlos', 'alcatel idol 3 5 5 6045y')
# ('Carlos', 'apple iphone 5s')
# ('Carlos', 'apple iphone 6')
# ('Carlos', 'blackberry curve 8520')
# ('Carlos', 'blackberry torch 9810')
# ('Carlo', 'apple iphone 5')
# ('Carlo', 'archos 50 platinum')
# ('Carlo', 'asus ze550kl')
# ('Carlo', 'asus zenfone max zc550kl')
# ('Carlo', 'blackberry z10')
# ('Bruno', 'apple iphone 5s')
# ('Bruno', 'archos 50 helium')
# ('Bruno', 'lg google nexus 5')
# ('Bruno', 'motorola moto x')
# ('Bruno', 'nokia 108')
# ('Brian', 'apple iphone 5')
# ('Brian', 'apple iphone 7 plus')
# ('Brian', 'blackberry z30')
# ('Brian', 'blu d610a')
# ('Brian', 'lg d820')
# ('Brandon', 'apple iphone 5c')
# ('Brandon', 'apple iphone 5s')
# ('Brandon', 'lg g2 mini')
# ('Brandon', 'lg optimus l9 p760')
# ('Brandon', 'nokia 6300')
# ('Bob', 'apple iphone 5s')
# ('Bob', 'apple iphone 7')
# ('Bob', 'blackberry z10')
# ('Bob', 'cubot x6')
# ('Bob', 'lg optimus net')
# ('Bill', 'blackberry curve 8530')
# ('Bill', 'htc one m7')
# ('Bill', 'huawei honor 8')
# ('Bill', 'lg g3 d855 657484')
# ('Bill', 'nokia 6303i')
# ('Bezlikiy_Djo', 'apple iphone 4')
# ('Bezlikiy_Djo', 'apple iphone 3gs')
# ('Bezlikiy_Djo', 'blackberry 9700')
# ('Bezlikiy_Djo', 'nokia 6131')
# ('Bezlikiy_Djo', 'nokia 6220 classic')
# ('Bert', 'apple iphone 4s')
# ('Bert', 'lg v10')
# ('Bert', 'samsung galaxy j7 prime')
# ('Bert', 'huawei p8 lite')
# ('Bert', 'apple iphone 5s')
# ('Bernd', 'acer liquid e700')
# ('Bernd', 'apple iphone se')
# ('Bernd', 'cubot x9')
# ('Bernd', 'microsoft lumia 640 dual sim')
# ('Bernd', 'nokia 2720 fold')
# ('Benjamin', 'alcatel one touch pixi 3')
# ('Benjamin', 'asus zenfone 3 max')
# ('Benjamin', 'htc one x')
# ('Benjamin', 'lg google nexus 5')
# ('Benjamin', 'pantech link jycp7040')
# ('Ben', 'apple iphone 5c')
# ('Ben', 'blackberry torch 9800')
# ('Ben', 'blu win hd')
# ('Ben', 'doro phoneeasy 622')
# ('Ben', 'htc desire')
# ('Bart', 'lg g5')
# ('Bart', 'huawei p10 plus')
# ('Bart', 'huawei p8')
# ('Bart', 'huawei p8 lite')
# ('Bart', 'samsung galaxy s7 789999')
# ('Barbara', 'alcatel one touch pop c7 7041d')
# ('Barbara', 'huawei p9 plus')
# ('Barbara', 'lg dare vx9700')
# ('Barbara', 'microsoft lumia 435')
# ('Barbara', 'nokia lumia 1520')
# ('Ashley', 'blu advance 4 0')
# ('Ashley', 'lg cosmos 2')
# ('Ashley', 'lg env')
# ('Ashley', 'lg g3 d855 657484')
# ('Ashley', 'lg vn250')
# ('Arun', 'lenovo ideaphone a680')
# ('Arun', 'nokia xl')
# ('Arun', 'oneplus 3')
# ('Arun', 'samsung c3530')
# ('Arun', 'lenovo a916')
# ('AnÃ´nimo', 'apple iphone 5s')
# ('AnÃ´nimo', 'asus zenfone 3')
# ('AnÃ´nimo', 'lenovo vibe k5')
# ('AnÃ´nimo', 'lg optimus g')
# ('AnÃ´nimo', 'lg optimus l3 ii e430 e425')
# ('AnÃ³nimo ', 'lg g3 d722')
# ('AnÃ³nimo ', 'lg l40g')
# ('AnÃ³nimo ', 'lg l90 d410')
# ('AnÃ³nimo ', 'lg optimus g')
# ('AnÃ³nimo ', 'lg optimus g pro')
# ('Antonio', 'acer liquid e2')
# ('Antonio', 'apple iphone 5s')
# ('Antonio', 'apple iphone 6 plus')
# ('Antonio', 'apple iphone 6s')
# ('Antonio', 'apple iphone 7')
# ('Anton', 'apple iphone 5s')
# ('Anton', 'motorola moto g')
# ('Anton', 'nokia lumia 620')
# ('Anton', 'samsung galaxy s ii')
# ('Anton', 'sony ericsson u8 vivaz pro')
# ('Anthony', 'apple iphone 5c')
# ('Anthony', 'blackberry curve 8520')
# ('Anthony', 'htc one m7')
# ('Anthony', 'huawei ascend mate 8')
# ('Anthony', 'huawei honor 6x')
# ('Anonyme', 'nokia n96')
# ('Anonyme', 'blackberry curve 8520')
# ('Anonyme', 'sony ericsson k850i')
# ('Anonyme', 'archos 50 diamond')
# ('Anonyme', 'sony ericsson t707i')
# ('Anonym', 'doro phoneeasy 612')
# ('Anonym', 'huawei nova')
# ('Anonym', 'nokia 3720')
# ('Anonym', 'nokia 5130 xpressmusic')
# ('Anonym', 'nokia lumia 635')
# ('Annie', 'cubot x9')
# ('Annie', 'doro phoneeasy 612')
# ('Annie', 'huawei p8')
# ('Annie', 'lg optimus net')
# ('Annie', 'pantech crossover')
# ('Anne', 'apple iphone 5s')
# ('Anne', 'huawei honor 4x')
# ('Anne', 'motorola moto g')
# ('Anne', 'sony ericson w580i')
# ('Anne', 'sony xperia m')
# ('Anna', 'alcatel ot 355')
# ('Anna', 'blu win hd')
# ('Anna', 'casio g zone ravine 2')
# ('Anna', 'htc desire 816')
# ('Anna', 'huawei mate 9')
# ('Anja', 'emporia elegance')
# ('Anja', 'htc desire c golf wildfire c')
# ('Anja', 'huawei ascend mate 7')
# ('Anja', 'lg g3 d855 657484')
# ('Anja', 'nokia c5 03')
# ('Anita', 'doogee x5 max')
# ('Anita', 'lg g6')
# ('Anita', 'lg optimus l7')
# ('Anita', 'motorola va76r')
# ('Anita', 'nokia asha 303')
# ('Angelo', 'apple iphone 5s')
# ('Angelo', 'blackberry 9330 curve 3g')
# ('Angelo', 'doogee dagger dg550')
# ('Angelo', 'doogee valencia 2 y100 pro')
# ('Angelo', 'elephone trunk')
# ('Angela', 'apple iphone 6s')
# ('Angela', 'asus ze500kl')
# ('Angela', 'asus zenfone 2 ze551ml')
# ('Angela', 'blu zoey')
# ('Angela', 'htc droid eris')
# ('Angel', 'apple iphone 4')
# ('Angel', 'doogee x5')
# ('Angel', 'doro phoneeasy 612')
# ('Angel', 'huawei ascend g6')
# ('Angel', 'huawei honor 4x')
# ('Andy', 'alcatel onetouch 1016g')
# ('Andy', 'apple iphone 5')
# ('Andy', 'apple iphone 5c')
# ('Andy', 'apple iphone 5s')
# ('Andy', 'apple iphone 6s')
# ('AndrÃ©', 'apple iphone 4')
# ('AndrÃ©', 'samsung ativ s')
# ('AndrÃ©', 'samsung galaxy a5 2016')
# ('AndrÃ©', 'sony xperia xz')
# ('AndrÃ©', 'huawei p8 lite')
# ('Andrew', 'apple iphone')
# ('Andrew', 'apple iphone 4')
# ('Andrew', 'apple iphone 5c')
# ('Andrew', 'blackberry z10')
# ('Andrew', 'doro phoneeasy 612')
# ('Andres', 'htc desire 610')
# ('Andres', 'jiayu g4s')
# ('Andres', 'motorola moto e')
# ('Andres', 'lg optimus l9 p760')
# ('Andres', 'microsoft lumia 640 dual sim')
# ('Andreas', 'apple iphone 6')
# ('Andreas', 'apple iphone 6s plus')
# ('Andreas', 'apple iphone 7')
# ('Andreas', 'cubot x15')
# ('Andreas', 'doro phoneeasy 612')
# ('Andrea', 'alcatel ot 991d')
# ('Andrea', 'apple iphone 5')
# ('Andrea', 'apple iphone 5c')
# ('Andrea', 'apple iphone 5s')
# ('Andrea', 'apple iphone 6 plus')
# ('Andre', 'asus zenfone 2 ze551ml')
# ('Andre', 'htc incredible s')
# ('Andre', 'htc one m7')
# ('Andre', 'microsoft lumia 435')
# ('Andre', 'microsoft lumia 640 dual sim')
# ('Andi', 'cubot note s')
# ('Andi', 'htc m8')
# ('Andi', 'htc wildfire s')
# ('Andi', 'huawei honor 6x')
# ('Andi', 'lg google nexus 5')
# ('Ana', 'apple iphone 4s')
# ('Ana', 'apple iphone 5c')
# ('Ana', 'doogee f5')
# ('Ana', 'htc one x')
# ('Ana', 'huawei p8')
# ('An??nimo', 'lg a275')
# ('An??nimo', 'motorola razr 432872')
# ('An??nimo', 'nokia asha 311')
# ('An??nimo', 'lg optimus l5')
# ('An??nimo', 'lg p725 optimus 3d max')
# ('Amy', 'apple iphone 4')
# ('Amy', 'huawei g630')
# ('Amy', 'motorola moto g4')
# ('Amy', 'nokia 105')
# ('Amy', 'nokia lumia 630')
# ('Amit', 'lenovo vibe k4 note')
# ('Amit', 'nokia 108')
# ('Amit', 'oneplus 3')
# ('Amit', 'oneplus 3t')
# ('Amit', 'xiaomi mi 4i')
# ('Amazon-Kunde', 'acer liquid e700')
# ('Amazon-Kunde', 'apple iphone 4')
# ('Amazon-Kunde', 'apple iphone 7')
# ('Amazon-Kunde', 'blackberry curve 9320')
# ('Amazon-Kunde', 'blackberry venice')
# ('Amazon customer', 'blackberry classic')
# ('Amazon customer', 'blackberry dtek60')
# ('Amazon customer', 'blu vivo xl')
# ('Amazon customer', 'elephone p6000')
# ('Amazon customer', 'huawei honor 6x')
# ('Amazon Kundenrezensionen', 'alcatel idol 3')
# ('Amazon Kundenrezensionen', 'apple iphone 6')
# ('Amazon Kundenrezensionen', 'blackberry q10')
# ('Amazon Kundenrezensionen', 'nokia c5')
# ('Amazon Kundenrezensionen', 'nokia lumia 1020')
# ('Amazon Kunde', 'alcatel onetouch pixi 4')
# ('Amazon Kunde', 'apple iphone 3g')
# ('Amazon Kunde', 'apple iphone 6 plus')
# ('Amazon Kunde', 'apple iphone 6s plus')
# ('Amazon Kunde', 'asus padfone 2')
# ('Amazon Customer', 'acer liquid e700')
# ('Amazon Customer', 'alcatel one touch 997d ot 997d')
# ('Amazon Customer', 'alcatel one touch idol 4s')
# ('Amazon Customer', 'alcatel one touch pop c5 5036d')
# ('Amazon Customer', 'alcatel onetouch go play')
# ('Amanda', 'lg kp500')
# ('Amanda', 'motorola va76r')
# ('Amanda', 'samsung galaxy s iii')
# ('Amanda', 'sony ericson w580i')
# ('Amanda', 'sony xperia e')
# ('Alvaro', 'lenovo a850')
# ('Alvaro', 'lg spirit c70 h440n')
# ('Alvaro', 'microsoft lumia 640 dual sim')
# ('Alvaro', 'microsoft lumia 950')
# ('Alvaro', 'sony ericsson xperia active')
# ('Alice', 'apple iphone 4s')
# ('Alice', 'blu tank ii')
# ('Alice', 'huawei p9 lite')
# ('Alice', 'samsung e1190')
# ('Alice', 'samsung galaxy s4 mini gt i9190 gt i9192 dual sim')
# ('Alias', 'apple iphone 5s')
# ('Alias', 'apple iphone 6s')
# ('Alias', 'asus zenfone 2')
# ('Alias', 'asus zenfone max zc550kl')
# ('Alias', 'htc desire 510')
# ('Ali', 'apple iphone 7 plus')
# ('Ali', 'doro phoneeasy 612')
# ('Ali', 'huawei ascend g620s')
# ('Ali', 'lg octane')
# ('Ali', 'motorola razr hd')
# ('Alfredo', 'alcatel one touch 890')
# ('Alfredo', 'asus ze550kl')
# ('Alfredo', 'blu vivo air')
# ('Alfredo', 'bq aquaris x5')
# ('Alfredo', 'doogee valencia 2 y100 pro')
# ('Alfonso', 'asus zenfone 2 ze551ml')
# ('Alfonso', 'bq aquaris x5')
# ('Alfonso', 'doogee homtom ht7')
# ('Alfonso', 'doogee x5 max pro')
# ('Alfonso', 'huawei p8')
# ('Alexis', 'blackberry 9330 curve 3g')
# ('Alexis', 'htc one max')
# ('Alexis', 'lg p710 optimus l7 ii')
# ('Alexis', 'motorola photon 4g')
# ('Alexis', 'samsung galaxy a3 2016')
# ('Alexandra', 'apple iphone 5c')
# ('Alexandra', 'emporia telme flip f210')
# ('Alexandra', 'nokia 2760')
# ('Alexandra', 'nokia lumia 730')
# ('Alexandra', 'samsung galaxy j5')
# ('Alexander', 'apple iphone 4s')
# ('Alexander', 'blackberry bold 9780')
# ('Alexander', 'blackberry z10')
# ('Alexander', 'cubot x10')
# ('Alexander', 'htc m8')
# ('Alex', 'apple iphone 4')
# ('Alex', 'apple iphone 5')
# ('Alex', 'apple iphone 6')
# ('Alex', 'asus zenfone 2 ze551ml')
# ('Alex', 'asus zenfone 5')
# ('Alessio', 'apple iphone 4s')
# ('Alessio', 'asus zenfone 2')
# ('Alessio', 'blackberry z30')
# ('Alessio', 'elephone p6000')
# ('Alessio', 'htc one sv')
# ('Alessandro', 'alcatel onetouch 20 04')
# ('Alessandro', 'apple iphone 5')
# ('Alessandro', 'apple iphone 5c')
# ('Alessandro', 'apple iphone 6s')
# ('Alessandro', 'asus zenfone 2 ze551ml')
# ('Alessandra', 'asus zenfone 2')
# ('Alessandra', 'motorola moto g')
# ('Alessandra', 'samsung galaxy note 5 sm n920f')
# ('Alessandra', 'sony xperia c')
# ('Alessandra', 'sony xperia z3plus')
# ('Alejandro', 'blu a310a')
# ('Alejandro', 'doogee dg580')
# ('Alejandro', 'google nexus 5x h791')
# ('Alejandro', 'microsoft lumia 535')
# ('Alejandro', 'microsoft lumia 640 xl')
# ('Ale', 'samsung galaxy s6 edge sm g925f')
# ('Ale', 'samsung galaxy s7 edge')
# ('Ale', 'sony xperia xa')
# ('Ale', 'alcatel onetouch pop c3 4033d')
# ('Ale', 'lg ke850 prada')
# ('Alberto', 'apple iphone 5s')
# ('Alberto', 'asus zenfone 3')
# ('Alberto', 'asus zenfone 3 max')
# ('Alberto', 'cubot note s')
# ('Alberto', 'doogee voyager2 dg310')
# ('Albert', 'acer liquid z3 duo')
# ('Albert', 'apple iphone 5s')
# ('Albert', 'doogee x5 max pro')
# ('Albert', 'htc 7 pro')
# ('Albert', 'lg g3 d855 657484')
# ('Alan', 'lg k4')
# ('Alan', 'motorola xt1225')
# ('Alan', 'nokia lumia 521')
# ('Alan', 'samsung galaxy s5 mini')
# ('Alan', 'samsung galaxy s6')
# ('Al', 'apple iphone 5s')
# ('Al', 'apple iphone 6')
# ('Al', 'motorola moto g')
# ('Al', 'motorola moto g3')
# ('Al', 'samsung galaxy rugby pro')
# ('Adrian', 'blackberry passport')
# ('Adrian', 'elephone p6000 pro')
# ('Adrian', 'htc 7 mozart')
# ('Adrian', 'htc one m7')
# ('Adrian', 'htc one x')
# ('Aditya', 'apple iphone 7')
# ('Aditya', 'htc one s')
# ('Aditya', 'lg google nexus 5')
# ('Aditya', 'meizu m2 note')
# ('Aditya', 'oneplus 3')
# ('Adam', 'blackberry classic')
# ('Adam', 'blackberry pearl 8130')
# ('Adam', 'htc desire')
# ('Adam', 'huawei ascend p7')
# ('Adam', 'huawei honor 4x')
# ('Abhishek', 'apple iphone 7')
# ('Abhishek', 'nokia lumia 730')
# ('Abhishek', 'oneplus 3')
# ('Abhishek', 'samsung galaxy e7')
# ('Abhishek', 'samsung galaxy j3 duos')
# ('Aaron', 'apple iphone 6 plus')
# ('Aaron', 'htc m8')
# ('Aaron', 'samsung galaxy j7')
# ('Aaron', 'samsung sch i500 showcase mesmerize')
# ('Aaron', 'sony xperia p')
# ('AJ', 'apple iphone 5c')
# ('AJ', 'blackberry passport')
# ('AJ', 'htc one s')
# ('AJ', 'motorola moto e')
# ('AJ', 'motorola xt1225')
# ('A', 'acer liquid e700')
# ('A', 'samsung galaxy j7 prime')
# ('A', 'samsung galaxy note 2')
# ('A', 'samsung galaxy s7 edge')
# ('A', 'sony xperia e4')
# ('?????\x80??????', 'acer cloudmobile')
# ('?????\x80??????', 'apple iphone 4s')
# ('?????\x80??????', 'apple iphone 5')
# ('?????\x80??????', 'htc one x')
# ('?????\x80??????', 'nokia asha 503')
# ('???????\x80????', 'apple iphone 4s')
# ('???????\x80????', 'htc desire sv')
# ('???????\x80????', 'huawei ascend d1')
# ('???????\x80????', 'lenovo k900')
# ('???????\x80????', 'nokia 112')
# ('?????????\x80????', 'apple iphone 4s')
# ('?????????\x80????', 'lg optimus l5 e610')
# ('?????????\x80????', 'nokia 701')
# ('?????????\x80????', 'samsung galaxy note')
# ('?????????\x80????', 'samsung galaxy s7710 xcover 2')
# ('?????????????????\x80', 'acer cloudmobile')
# ('?????????????????\x80', 'htc desire c golf wildfire c')
# ('?????????????????\x80', 'htc desire sv')
# ('?????????????????\x80', 'htc radar')
# ('?????????????????\x80', 'samsung galaxy note')
# ('????????????????', 'huawei honor')
# ('????????????????', 'nokia 603')
# ('????????????????', 'nokia asha 302')
# ('????????????????', 'nokia n9')
# ('????????????????', 'sony xperia s')
# ('?????????????? ??????????????', 'lg optimus l5')
# ('?????????????? ??????????????', 'samsung galaxy s duos s7562')
# ('?????????????? ??????????????', 'samsung galaxy s iii')
# ('?????????????? ??????????????', 'samsung gt i8160')
# ('?????????????? ??????????????', 'sony ericsson xperia arc s')
# ('?????????????? ????????????', 'lenovo k900')
# ('?????????????? ????????????', 'lg optimus vu')
# ('?????????????? ????????????', 'nokia asha 503')
# ('?????????????? ????????????', 'nokia lumia 820')
# ('?????????????? ????????????', 'philips w732')
# ('?????????????? ??????????', 'huawei ascend w1')
# ('?????????????? ??????????', 'philips w732')
# ('?????????????? ??????????', 'huawei ascend d1')
# ('?????????????? ??????????', 'nokia 301')
# ('?????????????? ??????????', 'samsung gt i8160')
# ('??????????????', 'apple iphone 5')
# ('??????????????', 'htc one x')
# ('??????????????', 'htc sensation xl')
# ('??????????????', 'huawei ascend d1')
# ('??????????????', 'lg optimus l5')
# ('???????????? ??????????????', 'htc one x')
# ('???????????? ??????????????', 'lenovo k900')
# ('???????????? ??????????????', 'lg p880 optimus 4x hd')
# ('???????????? ??????????????', 'nokia c2 05')
# ('???????????? ??????????????', 'philips w732')
# ('???????????? ??????????', 'htc desire sv')
# ('???????????? ??????????', 'htc sensation xe')
# ('???????????? ??????????', 'samsung s7262 duos galaxy ace')
# ('???????????? ??????????', 'sony xperia p')
# ('???????????? ??????????', 'sony xperia s')
# ('???????????? ????????', 'apple iphone 4s')
# ('???????????? ????????', 'huawei ascend w1')
# ('???????????? ????????', 'nokia 808')
# ('???????????? ????????', 'nokia x dual sim')
# ('???????????? ????????', 'samsung galaxy s iii')
# ('????????????', 'htc desire sv')
# ('????????????', 'lg optimus sol')
# ('????????????', 'nokia 603')
# ('????????????', 'sony ericsson xperia neo v')
# ('????????????', 'sony xperia v')
# ('??????????', 'apple iphone 4s')
# ('??????????', 'lg optimus l5')
# ('??????????', 'lg optimus sol')
# ('??????????', 'lg p880 optimus 4x hd')
# ('??????????', 'lg p940')
# ('????????', 'apple iphone 5')
# ('????????', 'htc explorer')
# ('????????', 'huawei ascend d1')
# ('????????', 'nokia asha 309')
# ('????????', 'samsung galaxy nexus')
# ('91mobiles Customer', 'htc one x9')
# ('91mobiles Customer', 'lenovo vibe x3')
# ('91mobiles Customer', 'lg v10')
# ('91mobiles Customer', 'oneplus x')
# ('91mobiles Customer', 'xiaomi redmi note 3 pro')
# ('.', 'alcatel one touch idol 4s')
# ('.', 'apple iphone se')
# ('.', 'htc 10')
# ('.', 'lg p990')
# ('.', 'nokia lumia 510')
# ('#', 'apple iphone 4')
# ('#', 'nokia 5230')
# ('#', 'nokia 5233')
# ('#', 'nokia 6120 classic')
# ('#', 'nokia 6680')

# %%
# Retrieve top 5 products for a particular user - Florian
for item,value in top5.iterrows():
  if item[0] == 'Florian':
    print(item)
# Out:
# ('Florian', 'cubot x9')
# ('Florian', 'htc 7 trophy')
# ('Florian', 'lenovo moto g4')
# ('Florian', 'motorola moto g')
# ('Florian', 'nokia lumia 1320')

# %%
# Retrieve top 5 products for a particular user - Dave
for item,value in top5.iterrows():
  if item[0] == 'Dave':
    print(item)
# Out:
# ('Dave', 'apple iphone 6s')
# ('Dave', 'apple iphone 7 plus')
# ('Dave', 'asus zenfone 2')
# ('Dave', 'elephone p9000')
# ('Dave', 'htc 10')

# %% [markdown]
# Try cross validation to get better results

# %%
svd_cv = cross_validate(svd_model,data, measures=['RMSE'], cv=3, verbose=False)
svd_cv['test_rmse'].mean()
# Out:
# 2.8704490027990044

# %%
knn_item_cv = cross_validate(knn_item,data, measures=['RMSE'], cv=3, verbose=False)
knn_item_cv['test_rmse'].mean()
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 2.8798326746914995

# %%
knn_user_cv = cross_validate(knn_user,data, measures=['RMSE'], cv=3, verbose=False)
knn_user_cv['test_rmse'].mean()
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 2.867927771050414

# %% [markdown]
# After using 3-fold cross validation, the KNN user-based model is the best model with RMSE of 2.868, while KNN item-based and SVD have RMSE of 2.88 and 2.87 respectively
